# %% [markdown]
# **Saad Khan and Nithun Selva**
#
# Spring 2025
#
# CS 444: Deep Learning
#
# Project 1: Deep Neural Networks
#
# #### Week 4: Batch normalization and learning rate decay
#
# The continued focus this week is on strategies for training deep neural networks.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

plt.style.use(['seaborn-v0_8-colorblind', 'seaborn-v0_8-darkgrid'])
plt.rcParams.update({'font.size': 20})

np.set_printoptions(suppress=True, precision=4)

# Automatically reload your external source code
# %load_ext autoreload
# %autoreload 2
# Out:
# 2025-03-13 20:03:19.988171: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-13 20:03:20.195471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741910600.274159     823 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741910600.294819     823 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-13 20:03:20.486010: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Task 9. Batch normalization
#
# Batch normalization is one of the most powerful techniques for effectively training very deep neural networks. Let's implement batch normalization in the deep learning library and experiment with how integrating it with VGG networks affects classification accuracy on CIFAR-10.

# %% [markdown]
# ### 9a. Implement batch normalization
#
# Implement the following methods / make the following changes:
#
# **Layer:**
# - Constructor: If you have not already done so, make instance variables for the two batch normalization related parameters.
# - `is_doing_batchnorm`
# - `init_batchnorm_params`: Initialize the batch normalization parameters. The gain, bias, mean, and standard deviation.
# - `__call__`: Update how you compute the forward pass through the layer. If we are doing batch norm AND the batch norm moving mean is not `None`, perform batch normalization on the net input before the layer's activation is computed.
#
# **Dense**:
# - `compute_batch_norm(net_in, eps=0.001)`: Updates the running mini-batch mean and standard deviation during training and performs batch normalization on the net input signal.
#
# **Conv2D**:
# - `compute_batch_norm(net_in, eps=0.001)`: Updates the running mini-batch mean and standard deviation during training and performs batch normalization on the net input signal.
#
# **VGGConvBlock** and **VGGDenseBlock**:
# - In the constructors, pass along the `do_batch_norm` parameter to constituent layers.

# %% [markdown]
# #### Test: `Dense` batch norm

# %%
from layers import Dense

# %%
print(30*'-', 'Test: Dense w/ linear (not training)', 30*'-')

tf.random.set_seed(0)
dense = Dense('Test', units=5, prev_layer_or_block=None, wt_init='he', activation='linear', do_batch_norm=True)
dense(tf.ones([1, 3]))
dense.init_batchnorm_params()

tf.random.set_seed(1)
net_acts = dense(tf.random.uniform([2, 3]))
print(f'Your net_acts (not in training mode) are\n{net_acts}')
print('They should be:')
print('''[[ 0.1316 -0.1246  0.867  -0.0392 -0.1553]
 [ 0.1964 -0.0568  0.3891 -0.4167 -0.5647]]''')

print(30*'-', 'Test: Dense w/ ReLU (not training)', 30*'-')

tf.random.set_seed(0)
dense = Dense('Test', units=5, prev_layer_or_block=None, wt_init='he', do_batch_norm=True)
dense(tf.ones([1, 3]))
dense.init_batchnorm_params()

tf.random.set_seed(1)
net_acts = dense(tf.random.uniform([2, 3]))
print(f'Your net_acts (not in training mode) are\n{net_acts}')
print('They should be:')
print('''[[0.1861 0.     1.2261 0.     0.    ]
 [0.2777 0.     0.5503 0.     0.    ]]''')
# Out:
# ------------------------------ Test: Dense w/ linear (not training) ------------------------------
# Your net_acts (not in training mode) are
# [[ 0.1316 -0.1246  0.867  -0.0392 -0.1553]
#  [ 0.1964 -0.0568  0.3891 -0.4167 -0.5647]]
# They should be:
# [[ 0.1316 -0.1246  0.867  -0.0392 -0.1553]
#  [ 0.1964 -0.0568  0.3891 -0.4167 -0.5647]]
# ------------------------------ Test: Dense w/ ReLU (not training) ------------------------------
# Your net_acts (not in training mode) are
# [[0.1861 0.     1.2261 0.     0.    ]
#  [0.2777 0.     0.5503 0.     0.    ]]
# They should be:
# [[0.1861 0.     1.2261 0.     0.    ]
#  [0.2777 0.     0.5503 0.     0.    ]]

# %%
print(30*'-', 'Test: Dense w/ linear (training)', 30*'-')
tf.random.set_seed(0)
dense = Dense('Test', units=4, prev_layer_or_block=None, wt_init='he', activation='linear', do_batch_norm=True)
dense(tf.ones([1, 6]))
dense.init_batchnorm_params()

dense.set_mode(True)

tf.random.set_seed(1)
net_acts = dense(tf.random.uniform([3, 6]))
print(f'Your net_acts (in training mode) are\n{net_acts}')
print('They should be:')
print('''[[-1.2303  1.1081 -0.1128  1.1738]
 [ 1.2109  0.16   -1.1564 -1.2605]
 [ 0.0194 -1.2681  1.2692  0.0866]]''')

print(30*'-', 'Test: Dense w/ ReLU (training)', 30*'-')
tf.random.set_seed(0)
dense = Dense('Test', units=5, prev_layer_or_block=None, wt_init='he', do_batch_norm=True)
dense(tf.ones([1, 3]))
dense.init_batchnorm_params()

dense.set_mode(True)

tf.random.set_seed(1)
net_acts = dense(tf.random.uniform([2, 3]))
print(f'Your net_acts (in training mode) are\n{net_acts}')
print('They should be:')
print('''[[0.     0.     0.9971 0.9963 0.9966]
 [0.9787 0.9796 0.     0.     0.    ]]''')
# Out:
# ------------------------------ Test: Dense w/ linear (training) ------------------------------
# Your net_acts (in training mode) are
# [[-1.2303  1.1081 -0.1128  1.1738]
#  [ 1.2109  0.16   -1.1564 -1.2605]
#  [ 0.0194 -1.2681  1.2692  0.0866]]
# They should be:
# [[-1.2303  1.1081 -0.1128  1.1738]
#  [ 1.2109  0.16   -1.1564 -1.2605]
#  [ 0.0194 -1.2681  1.2692  0.0866]]
# ------------------------------ Test: Dense w/ ReLU (training) ------------------------------
# Your net_acts (in training mode) are
# [[0.     0.     0.9971 0.9963 0.9966]
#  [0.9787 0.9796 0.     0.     0.    ]]
# They should be:
# [[0.     0.     0.9971 0.9963 0.9966]
#  [0.9787 0.9796 0.     0.     0.    ]]

# %%
print(30*'-', 'Test: Dense w/ ReLU multiple mini-batches', 30*'-')
tf.random.set_seed(0)
dense = Dense('Test', units=5, prev_layer_or_block=None, wt_init='he', do_batch_norm=True)
dense(tf.ones([1, 3]))
dense.init_batchnorm_params()

dense.set_mode(True)

tf.random.set_seed(1)
for i in range(5):
    net_acts = dense(tf.random.uniform([2, 3]))
print(f'Your net_acts after some mini-batches are\n{net_acts}')
print('They should be:')
print('''[[0.9975 0.9953 0.     0.     0.    ]
 [0.     0.     0.9984 0.9953 0.9946]]''')

dense.set_mode(False)

tf.random.set_seed(2)
net_acts1 = dense(tf.random.uniform([2, 3]))
net_acts2 = dense(tf.random.uniform([2, 3]))

print('After processing mini-batches in non-training mode, the net_acts are:')
print(net_acts1.numpy())
print(net_acts2.numpy())
print('and should be:')
print('''[[0.2089 0.     0.5334 0.     0.    ]
 [0.2175 0.     1.505  0.     0.    ]]
[[0.8584 0.0224 1.0932 0.     0.    ]
 [1.1234 0.2351 0.2997 0.     0.    ]]''')
# Out:
# ------------------------------ Test: Dense w/ ReLU multiple mini-batches ------------------------------
# Your net_acts after some mini-batches are
# [[0.9975 0.9953 0.     0.     0.    ]
#  [0.     0.     0.9984 0.9953 0.9946]]
# They should be:
# [[0.9975 0.9953 0.     0.     0.    ]
#  [0.     0.     0.9984 0.9953 0.9946]]
# After processing mini-batches in non-training mode, the net_acts are:
# [[0.2089 0.     0.5334 0.     0.    ]
#  [0.2175 0.     1.505  0.     0.    ]]
# [[0.8584 0.0224 1.0932 0.     0.    ]
#  [1.1234 0.2351 0.2997 0.     0.    ]]
# and should be:
# [[0.2089 0.     0.5334 0.     0.    ]
#  [0.2175 0.     1.505  0.     0.    ]]
# [[0.8584 0.0224 1.0932 0.     0.    ]
#  [1.1234 0.2351 0.2997 0.     0.    ]]

# %% [markdown]
# #### Test: `Conv2D` batch norm

# %%
from layers import Conv2D

# %%
print(30*'-', 'Test: Conv2D w/ linear (not training)', 30*'-')

tf.random.set_seed(0)
conv = Conv2D('Test', units=4, kernel_size=(2, 2), prev_layer_or_block=None, wt_init='he', activation='linear',
              do_batch_norm=True)
conv(tf.ones([1, 2, 2, 3]))
conv.init_batchnorm_params()

tf.random.set_seed(1)
net_acts = conv(tf.random.uniform([2, 2, 2, 3]))
print(f'Your net_acts (not in training mode) are\n{net_acts}')
print('They should be:')
print('''[[[[-0.4583  0.3257 -0.7078 -0.3702]
   [-0.1189  0.2832 -0.1614 -0.0745]]

  [[ 0.4845  0.4109 -0.5069 -0.2724]
   [ 0.1433  0.2664 -0.2008 -0.0392]]]


 [[[-0.2477  0.4331 -0.2983 -0.2121]
   [-0.0728  0.2052 -0.1844  0.1303]]

  [[ 0.2266  0.4893 -0.3521 -0.0567]
   [ 0.0542  0.0702 -0.0703 -0.0319]]]]''')
# Out:
# ------------------------------ Test: Conv2D w/ linear (not training) ------------------------------
# Your net_acts (not in training mode) are
# [[[[-0.4583  0.3257 -0.7078 -0.3702]
#    [-0.1189  0.2832 -0.1614 -0.0745]]
#
#   [[ 0.4845  0.4109 -0.5069 -0.2724]
#    [ 0.1433  0.2664 -0.2008 -0.0392]]]
#
#
#  [[[-0.2477  0.4331 -0.2983 -0.2121]
#    [-0.0728  0.2052 -0.1844  0.1303]]
#
#   [[ 0.2266  0.4893 -0.3521 -0.0567]
#    [ 0.0542  0.0702 -0.0703 -0.0319]]]]
# They should be:
# [[[[-0.4583  0.3257 -0.7078 -0.3702]
#    [-0.1189  0.2832 -0.1614 -0.0745]]
#
#   [[ 0.4845  0.4109 -0.5069 -0.2724]
#    [ 0.1433  0.2664 -0.2008 -0.0392]]]
#
#
#  [[[-0.2477  0.4331 -0.2983 -0.2121]
#    [-0.0728  0.2052 -0.1844  0.1303]]
#
#   [[ 0.2266  0.4893 -0.3521 -0.0567]
#    [ 0.0542  0.0702 -0.0703 -0.0319]]]]

# %%
print(30*'-', 'Test: Conv2D w/ linear (training)', 30*'-')

tf.random.set_seed(0)
conv = Conv2D('Test', units=4, kernel_size=(2, 2), prev_layer_or_block=None, wt_init='he', activation='linear',
              do_batch_norm=True)
conv(tf.ones([1, 2, 2, 3]))
conv.init_batchnorm_params()

conv.set_mode(True)

tf.random.set_seed(1)
net_acts = conv(tf.random.uniform([2, 2, 2, 3]))
print(f'Your net_acts (not in training mode) are\n{net_acts}')
print('They should be:')
print('''[[[[-1.6719  0.1188 -2.0219 -1.6977]
   [-0.4375 -0.2133  0.7571  0.2757]]

  [[ 1.7572  0.7852 -1.     -1.0448]
   [ 0.5163 -0.3449  0.5564  0.5117]]]


 [[[-0.9058  0.9583  0.0608 -0.6427]
   [-0.2695 -0.8235  0.64    1.6431]]

  [[ 0.8191  1.3981 -0.2129  0.3946]
   [ 0.1922 -1.8786  1.2204  0.5601]]]]''')
# Out:
# ------------------------------ Test: Conv2D w/ linear (training) ------------------------------
# Your net_acts (not in training mode) are
# [[[[-1.6719  0.1188 -2.0219 -1.6977]
#    [-0.4375 -0.2133  0.7571  0.2757]]
#
#   [[ 1.7572  0.7852 -1.     -1.0448]
#    [ 0.5163 -0.3449  0.5564  0.5117]]]
#
#
#  [[[-0.9058  0.9583  0.0608 -0.6427]
#    [-0.2695 -0.8235  0.64    1.6431]]
#
#   [[ 0.8191  1.3981 -0.2129  0.3946]
#    [ 0.1922 -1.8786  1.2204  0.5601]]]]
# They should be:
# [[[[-1.6719  0.1188 -2.0219 -1.6977]
#    [-0.4375 -0.2133  0.7571  0.2757]]
#
#   [[ 1.7572  0.7852 -1.     -1.0448]
#    [ 0.5163 -0.3449  0.5564  0.5117]]]
#
#
#  [[[-0.9058  0.9583  0.0608 -0.6427]
#    [-0.2695 -0.8235  0.64    1.6431]]
#
#   [[ 0.8191  1.3981 -0.2129  0.3946]
#    [ 0.1922 -1.8786  1.2204  0.5601]]]]

# %%
print(30*'-', 'Test: Conv2D w/ ReLU multiple mini-batches', 30*'-')
tf.random.set_seed(0)
conv = Conv2D('Test', units=4, kernel_size=(2, 2), prev_layer_or_block=None, wt_init='he', do_batch_norm=True)
conv(tf.ones([1, 2, 2, 3]))
conv.init_batchnorm_params()

conv.set_mode(True)

tf.random.set_seed(1)
for i in range(5):
    net_acts = conv(tf.random.uniform([2, 2, 2, 3]))
print(f'Your net_acts after some mini-batches are\n{net_acts}')
print('They should be:')
print('''[[[[0.     0.     0.252  0.    ]
   [0.     0.1891 1.3142 0.4295]]

  [[1.1739 0.     0.0018 0.4892]
   [0.7065 0.     0.2646 0.7403]]]


 [[[0.     1.7817 0.     0.    ]
   [0.     0.447  0.8604 0.5298]]

  [[1.1745 0.8703 0.     0.5416]
   [0.7664 0.     0.2116 0.6486]]]]''')
# Out:
# ------------------------------ Test: Conv2D w/ ReLU multiple mini-batches ------------------------------
# Your net_acts after some mini-batches are
# [[[[0.     0.     0.252  0.    ]
#    [0.     0.1891 1.3142 0.4295]]
#
#   [[1.1739 0.     0.0018 0.4892]
#    [0.7065 0.     0.2646 0.7403]]]
#
#
#  [[[0.     1.7817 0.     0.    ]
#    [0.     0.447  0.8604 0.5298]]
#
#   [[1.1745 0.8703 0.     0.5416]
#    [0.7664 0.     0.2116 0.6486]]]]
# They should be:
# [[[[0.     0.     0.252  0.    ]
#    [0.     0.1891 1.3142 0.4295]]
#
#   [[1.1739 0.     0.0018 0.4892]
#    [0.7065 0.     0.2646 0.7403]]]
#
#
#  [[[0.     1.7817 0.     0.    ]
#    [0.     0.447  0.8604 0.5298]]
#
#   [[1.1745 0.8703 0.     0.5416]
#    [0.7664 0.     0.2116 0.6486]]]]

# %%
conv.set_mode(False)

tf.random.set_seed(2)
for i in range(2):
    net_acts = conv(tf.random.uniform([2, 2, 2, 3]))

print('After processing mini-batches in non-training mode, the net_acts are:')
print(net_acts.numpy())
print('and should be:')
print('''[[[[0.     0.0107 0.     0.    ]
   [0.     0.2271 0.3021 0.    ]]

  [[0.0629 0.0541 0.     0.0349]
   [0.     0.3308 0.     0.1565]]]


 [[[0.     0.4355 0.     0.    ]
   [0.     0.     0.2244 0.4117]]

  [[0.0396 0.2184 0.     0.058 ]
   [0.4179 0.3454 0.     0.    ]]]]''')
# Out:
# After processing mini-batches in non-training mode, the net_acts are:
# [[[[0.     0.0107 0.     0.    ]
#    [0.     0.2271 0.3021 0.    ]]
#
#   [[0.0629 0.0541 0.     0.0349]
#    [0.     0.3308 0.     0.1565]]]
#
#
#  [[[0.     0.4355 0.     0.    ]
#    [0.     0.     0.2244 0.4117]]
#
#   [[0.0396 0.2184 0.     0.058 ]
#    [0.4179 0.3454 0.     0.    ]]]]
# and should be:
# [[[[0.     0.0107 0.     0.    ]
#    [0.     0.2271 0.3021 0.    ]]
#
#   [[0.0629 0.0541 0.     0.0349]
#    [0.     0.3308 0.     0.1565]]]
#
#
#  [[[0.     0.4355 0.     0.    ]
#    [0.     0.     0.2244 0.4117]]
#
#   [[0.0396 0.2184 0.     0.058 ]
#    [0.4179 0.3454 0.     0.    ]]]]

# %% [markdown]
# ### 9b. Create VGG networks that use batch normalization
#
# In `vgg_nets.py`, create the `VGG4Plus`, `VGG15Plus`, and `VGG15PlusPlus` networks. These are the same as the corresponding nets you have already implemented, except these networks have batch normalization throughout in the conv and dense layers. The `VGG15PlusPlus` network differs from `VGG15Plus` in the use of dropout in the all of the conv blocks (not just before the final dense layer). This should be quick with some copy-pasting.
#
# **NOTE:** If your net_acts below are off in some cases by one number in the right-most least significant decimal place **that is fine!**.

# %%
from vgg_nets import VGG4Plus, VGG15Plus, VGG15PlusPlus

# %% [markdown]
# #### Test: VGG4Plus

# %%
v = VGG4Plus(C=3, input_feats_shape=(32, 32, 3), wt_init='he')
v.compile()
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 3]
# Dropout layer output(Dropout) shape: [1, 128]
# Dense layer output(Dense_1) shape: [1, 128]
# Flatten layer output(Flatten) shape: [1, 16384]
# MaxPool2D layer output(MaxPool_1) shape: [1, 16, 16, 64]
# Conv2D layer output(Conv2D_2) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_1) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------

# %% [markdown]
# The above should print:
#
# ```
# ---------------------------------------------------------------------------
# Dense layer output(output) shape: [1, 3]
# Dropout layer output(dropout1) shape: [1, 128]
# Dense layer output(dense1) shape: [1, 128]
# Flatten layer output(flat) shape: [1, 16384]
# MaxPool2D layer output(maxpool1) shape: [1, 16, 16, 64]
# Conv2D layer output(conv2) shape: [1, 32, 32, 64]
# Conv2D layer output(conv1) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# ```

# %%
tf.random.set_seed(0)
v = VGG4Plus(C=3, input_feats_shape=(32, 32, 5), wt_init='he')
tf.random.set_seed(1)
net_acts = v(tf.random.uniform([2, 32, 32, 5]))

print(f'Your net_acts are\n{net_acts.numpy()} and should be')
print('''[[0.2328 0.6381 0.1291]
 [0.2    0.6335 0.1664]]''')
# Out:
# Your net_acts are
# [[0.2328 0.6381 0.1291]
#  [0.2    0.6335 0.1664]] and should be
# [[0.2328 0.6381 0.1291]
#  [0.2    0.6335 0.1664]]

# %% [markdown]
# #### Test: VGG15Plus

# %%
v = VGG15Plus(C=7, input_feats_shape=(32, 32, 3), wt_init='he')
v.compile()
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 7]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------

# %% [markdown]
# The above should print:
#
# ```
# ---------------------------------------------------------------------------
# Dense layer output(output) shape: [1, 7]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense0) shape: [1, 512]
# Flatten layer output(flat) shape: [1, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool2) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock4/conv2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv0) shape: [1, 2, 2, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock3/conv2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock3/conv1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock3/conv0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool2) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool2) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool2) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# ```

# %%
tf.random.set_seed(0)
v = VGG15Plus(C=7, input_feats_shape=(32, 32, 3), wt_init='he')
tf.random.set_seed(1)
net_acts = v(tf.random.uniform([2, 32, 32, 3]))

print(f'Your net_acts are\n{net_acts.numpy()} and should be')
print('''[[0.0607 0.0949 0.0982 0.0789 0.3175 0.091  0.2587]
 [0.0693 0.0891 0.0968 0.0766 0.3231 0.0881 0.257 ]]''')
# Out:
# Your net_acts are
# [[0.0607 0.095  0.0982 0.0789 0.3175 0.091  0.2588]
#  [0.0693 0.0891 0.0968 0.0766 0.323  0.0881 0.257 ]] and should be
# [[0.0607 0.0949 0.0982 0.0789 0.3175 0.091  0.2587]
#  [0.0693 0.0891 0.0968 0.0766 0.3231 0.0881 0.257 ]]

# %% [markdown]
# #### Test: VGG15PlusPlus

# %%
v = VGG15PlusPlus(C=5, input_feats_shape=(32, 32, 3), wt_init='he')
v.compile()
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 5]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------

# %% [markdown]
# The above should print:
#
# ```
# ---------------------------------------------------------------------------
# Dense layer output(output) shape: [1, 5]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense0) shape: [1, 512]
# Flatten layer output(flat) shape: [1, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool2) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock4/conv2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv0) shape: [1, 2, 2, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock3/maxpool2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock3/conv2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock3/conv1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock3/conv0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool2) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool2) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool2) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# ```

# %%
tf.random.set_seed(0)
v = VGG15PlusPlus(C=5, input_feats_shape=(32, 32, 3), wt_init='he')
tf.random.set_seed(1)
net_acts = v(tf.random.uniform([2, 32, 32, 3]))

print(f'Your net_acts are\n{net_acts.numpy()} and should be')
print('''[[0.0962 0.2981 0.2029 0.3189 0.0838]
 [0.0893 0.2785 0.2156 0.3299 0.0868]]''')
# Out:
# Your net_acts are
# [[0.0963 0.2981 0.2028 0.319  0.0838]
#  [0.0893 0.2783 0.2156 0.3299 0.0868]] and should be
# [[0.0962 0.2981 0.2029 0.3189 0.0838]
#  [0.0893 0.2785 0.2156 0.3299 0.0868]]

# %% [markdown]
# ### 9c. Trial run of training VGG4Plus, VGG15Plus, and VGG15PlusPlus on CIFAR-10
#
# Load in CIFAR-10 below and train the 3 networks that use batch normalization for `1` epoch. Use the AdamW optimizer and otherwise keep default hyperparameters. Print out the test accuracy after teach training run. You should get (*approximately*):
#
# ```
# VGG4Plus test acc: 61.41
# VGG15Plus test acc: 37.71
# VGG15PlusPlus test acc: 22.29
# ```

# %%
from datasets import get_dataset

# %%
x_train, y_train, x_val, y_val, x_test, y_test, classnames = get_dataset("cifar10")
# Out:
# I0000 00:00:1741910632.999574     823 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5564 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
# Configure batch normalization networks and training
batch_norm_networks = [
    {"name": "VGG4Plus", "model": VGG4Plus},
    {"name": "VGG15Plus", "model": VGG15Plus},
    {"name": "VGG15PlusPlus", "model": VGG15PlusPlus}
]

# Train each network for 1 epoch and evaluate
for network in batch_norm_networks:
    print(f"\nTraining {network['name']}...")
    
    # Clear session and set seeds
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)
    
    # Create model with batch normalization
    model = network["model"](C=10,input_feats_shape=(32, 32, 3))
    
    # Compile with AdamW optimizer
    model.compile(optimizer='adamw', loss='cross_entropy')
    
    # Train for 1 epoch
    model.fit(x_train, y_train, max_epochs=1)
    
    # Evaluate on test set
    test_acc, _ = model.evaluate(x_test, y_test)
    print(f"{network['name']} test acc: {test_acc.numpy()*100:.2f}")
# Out:
# Training VGG4Plus...
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# Dropout layer output(Dropout) shape: [1, 128]
# Dense layer output(Dense_1) shape: [1, 128]
# Flatten layer output(Flatten) shape: [1, 16384]
# MaxPool2D layer output(MaxPool_1) shape: [1, 16, 16, 64]
# Conv2D layer output(Conv2D_2) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_1) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1 completed in 3.12 seconds.
# Finished training after 1 epochs!
# VGG4Plus test acc: 60.60
#
# Training VGG15Plus...
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1 completed in 11.38 seconds.
# Finished training after 1 epochs!
# VGG15Plus test acc: 37.37
#
# Training VGG15PlusPlus...
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1 completed in 12.59 seconds.
# Finished training after 1 epochs!
# VGG15PlusPlus test acc: 35.37

# %% [markdown]
# ### 9d. Train VGG4Plus, VGG15Plus, and VGG15PlusPlus on CIFAR-10
#
# Now that the networks have been tested, do a full training session with the following networks on CIFAR-10:
# - VGG4Plus
# - VGG15
# - VGG15Plus
# - VGG15PlusPlus
#
# Use default hyperparameters except:
# - Use AdamW optimizer.
# - Use He initialization
# - Use a patience of `4`. *If your earlier early stopping test did not end in the same number of epochs as the test code, you might want to try a patience of 5 or 6.*
#
# After training each net, store/record:
# 1. the network's final test accuracy.
# 2. the history of training loss (averaged across mini-batches, so one per epoch).
# 3. the history of validation loss (checked every epoch).
# 4. the history of validation accuracy (checked every epoch).
#
# **Notes:**
# - Set random seed before creating each net for consistency.
# - Use `tf.keras.backend.clear_session()` before creating each of the network to help prevent the memory used from growing.
#
# Training these networks should take ~30 minutes.

# %%
from vgg_nets import VGG15

# %%
# Configure networks for training
networks = [
    {"name": "VGG4Plus", "model": VGG4Plus},
    {"name": "VGG15", "model": VGG15},
    {"name": "VGG15Plus", "model": VGG15Plus},
    {"name": "VGG15PlusPlus", "model": VGG15PlusPlus}
]

# Store results
results = []

# Train each network
for network in networks:
    print(f"\n=== Training {network['name']} ===")
    
    # Clear session and set seeds
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)
    
    # Create model
    model = network["model"](C=10,input_feats_shape=(32, 32, 3),wt_init='he')
    
    # Compile with AdamW optimizer
    model.compile(optimizer='adamw', loss='cross_entropy')
    
    # Train with early stopping
    print(f"Starting training for {network['name']}...")
    train_loss_hist, val_loss_hist, val_acc_hist, epochs = model.fit(x_train,y_train,x_val,y_val,patience=5)
    print(f"Finished training {network['name']} for {epochs} epochs")
    
    # Evaluate on test set
    test_acc, test_loss = model.evaluate(x_test, y_test)
    
    # Store results
    results.append({
        "name": network["name"],
        "test_acc": test_acc.numpy(),
        "epochs": epochs,
        "train_loss": train_loss_hist,
        "val_loss": val_loss_hist,
        "val_acc": val_acc_hist
    })
    
    print(f"{network['name']} - Test Accuracy: {test_acc.numpy()*100:.2f}%, Training epochs: {epochs}")
# Out:
# === Training VGG4Plus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# Dropout layer output(Dropout) shape: [1, 128]
# Dense layer output(Dense_1) shape: [1, 128]
# Flatten layer output(Flatten) shape: [1, 16384]
# MaxPool2D layer output(MaxPool_1) shape: [1, 16, 16, 64]
# Conv2D layer output(Conv2D_2) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_1) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG4Plus...
# Epoch 1/10000 - Train Loss: 1.3424, Val Loss: 1.0451, Val Acc: 0.6324
# Epoch 1 completed in 3.58 seconds.
# Epoch 2/10000 - Train Loss: 0.9791, Val Loss: 0.9071, Val Acc: 0.6759
# Epoch 2 completed in 0.89 seconds.
# Epoch 3/10000 - Train Loss: 0.8385, Val Loss: 0.9159, Val Acc: 0.6843
# Epoch 3 completed in 0.88 seconds.
# Epoch 4/10000 - Train Loss: 0.7331, Val Loss: 0.9174, Val Acc: 0.6729
# Epoch 4 completed in 0.88 seconds.
# Epoch 5/10000 - Train Loss: 0.6328, Val Loss: 0.8657, Val Acc: 0.7045
# Epoch 5 completed in 0.89 seconds.
# Epoch 6/10000 - Train Loss: 0.5429, Val Loss: 0.8459, Val Acc: 0.7208
# Epoch 6 completed in 0.89 seconds.
# Epoch 7/10000 - Train Loss: 0.4667, Val Loss: 0.8979, Val Acc: 0.7119
# Epoch 7 completed in 0.89 seconds.
# Epoch 8/10000 - Train Loss: 0.3973, Val Loss: 0.9849, Val Acc: 0.6963
# Epoch 8 completed in 0.89 seconds.
# Epoch 9/10000 - Train Loss: 0.3431, Val Loss: 1.0402, Val Acc: 0.6963
# Epoch 9 completed in 0.88 seconds.
# Early stopping at epoch 10
# Finished training after 10 epochs!
# Finished training VGG4Plus for 10 epochs
# VGG4Plus - Test Accuracy: 68.82%, Training epochs: 10
#
# === Training VGG15 ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15...
# Epoch 1/10000 - Train Loss: 1.9094, Val Loss: 1.5989, Val Acc: 0.3644
# Epoch 1 completed in 6.01 seconds.
# Epoch 2/10000 - Train Loss: 1.4572, Val Loss: 1.2432, Val Acc: 0.5421
# Epoch 2 completed in 2.76 seconds.
# Epoch 3/10000 - Train Loss: 1.1604, Val Loss: 1.0660, Val Acc: 0.6196
# Epoch 3 completed in 2.75 seconds.
# Epoch 4/10000 - Train Loss: 0.9656, Val Loss: 1.1428, Val Acc: 0.6314
# Epoch 4 completed in 2.76 seconds.
# Epoch 5/10000 - Train Loss: 0.8364, Val Loss: 0.8236, Val Acc: 0.7246
# Epoch 5 completed in 2.75 seconds.
# Epoch 6/10000 - Train Loss: 0.7437, Val Loss: 0.7879, Val Acc: 0.7342
# Epoch 6 completed in 2.76 seconds.
# Epoch 7/10000 - Train Loss: 0.6735, Val Loss: 0.7445, Val Acc: 0.7536
# Epoch 7 completed in 2.75 seconds.
# Epoch 8/10000 - Train Loss: 0.6237, Val Loss: 0.7076, Val Acc: 0.7726
# Epoch 8 completed in 2.76 seconds.
# Epoch 9/10000 - Train Loss: 0.5847, Val Loss: 0.6986, Val Acc: 0.7768
# Epoch 9 completed in 2.76 seconds.
# Epoch 10/10000 - Train Loss: 0.5489, Val Loss: 0.6476, Val Acc: 0.7825
# Epoch 10 completed in 2.76 seconds.
# Epoch 11/10000 - Train Loss: 0.5226, Val Loss: 0.7399, Val Acc: 0.7636
# Epoch 11 completed in 2.74 seconds.
# Epoch 12/10000 - Train Loss: 0.5221, Val Loss: 0.7655, Val Acc: 0.7618
# Epoch 12 completed in 2.76 seconds.
# Epoch 13/10000 - Train Loss: 0.4870, Val Loss: 0.6674, Val Acc: 0.7843
# Epoch 13 completed in 2.78 seconds.
# Epoch 14/10000 - Train Loss: 0.4707, Val Loss: 0.6209, Val Acc: 0.8087
# Epoch 14 completed in 2.78 seconds.
# Epoch 15/10000 - Train Loss: 0.4570, Val Loss: 0.5802, Val Acc: 0.8153
# Epoch 15 completed in 2.76 seconds.
# Epoch 16/10000 - Train Loss: 0.4439, Val Loss: 0.6362, Val Acc: 0.8049
# Epoch 16 completed in 2.71 seconds.
# Epoch 17/10000 - Train Loss: 0.4363, Val Loss: 0.5896, Val Acc: 0.8201
# Epoch 17 completed in 2.70 seconds.
# Epoch 18/10000 - Train Loss: 0.4251, Val Loss: 0.5932, Val Acc: 0.8023
# Epoch 18 completed in 2.77 seconds.
# Early stopping at epoch 19
# Finished training after 19 epochs!
# Finished training VGG15 for 19 epochs
# VGG15 - Test Accuracy: 78.95%, Training epochs: 19
#
# === Training VGG15Plus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15Plus...
# Epoch 1/10000 - Train Loss: 1.4021, Val Loss: 2.2656, Val Acc: 0.3343
# Epoch 1 completed in 12.62 seconds.
# Epoch 2/10000 - Train Loss: 0.8962, Val Loss: 1.4246, Val Acc: 0.4876
# Epoch 2 completed in 3.33 seconds.
# Epoch 3/10000 - Train Loss: 0.7250, Val Loss: 1.2288, Val Acc: 0.5827
# Epoch 3 completed in 3.33 seconds.
# Epoch 4/10000 - Train Loss: 0.6207, Val Loss: 2.2420, Val Acc: 0.3450
# Epoch 4 completed in 3.30 seconds.
# Epoch 5/10000 - Train Loss: 0.5477, Val Loss: 1.5690, Val Acc: 0.5188
# Epoch 5 completed in 3.32 seconds.
# Epoch 6/10000 - Train Loss: 0.4889, Val Loss: 1.0506, Val Acc: 0.6575
# Epoch 6 completed in 3.32 seconds.
# Epoch 7/10000 - Train Loss: 0.4486, Val Loss: 1.1220, Val Acc: 0.6310
# Epoch 7 completed in 3.30 seconds.
# Epoch 8/10000 - Train Loss: 0.4158, Val Loss: 0.9613, Val Acc: 0.7029
# Epoch 8 completed in 3.32 seconds.
# Epoch 9/10000 - Train Loss: 0.3882, Val Loss: 1.0527, Val Acc: 0.6725
# Epoch 9 completed in 3.31 seconds.
# Epoch 10/10000 - Train Loss: 0.3695, Val Loss: 0.9208, Val Acc: 0.7067
# Epoch 10 completed in 3.32 seconds.
# Epoch 11/10000 - Train Loss: 0.3475, Val Loss: 0.7736, Val Acc: 0.7532
# Epoch 11 completed in 3.33 seconds.
# Epoch 12/10000 - Train Loss: 0.3287, Val Loss: 0.6269, Val Acc: 0.8013
# Epoch 12 completed in 3.32 seconds.
# Epoch 13/10000 - Train Loss: 0.3235, Val Loss: 1.2952, Val Acc: 0.6158
# Epoch 13 completed in 3.32 seconds.
# Epoch 14/10000 - Train Loss: 0.3153, Val Loss: 0.9868, Val Acc: 0.6871
# Epoch 14 completed in 3.27 seconds.
# Epoch 15/10000 - Train Loss: 0.3097, Val Loss: 0.8594, Val Acc: 0.7368
# Epoch 15 completed in 3.28 seconds.
# Early stopping at epoch 16
# Finished training after 16 epochs!
# Finished training VGG15Plus for 16 epochs
# VGG15Plus - Test Accuracy: 73.83%, Training epochs: 16
#
# === Training VGG15PlusPlus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15PlusPlus...
# Epoch 1/10000 - Train Loss: 1.8713, Val Loss: 2.1820, Val Acc: 0.3243
# Epoch 1 completed in 14.04 seconds.
# Epoch 2/10000 - Train Loss: 1.2379, Val Loss: 1.4627, Val Acc: 0.5196
# Epoch 2 completed in 3.35 seconds.
# Epoch 3/10000 - Train Loss: 0.9803, Val Loss: 1.5548, Val Acc: 0.4896
# Epoch 3 completed in 3.37 seconds.
# Epoch 4/10000 - Train Loss: 0.8641, Val Loss: 1.3802, Val Acc: 0.5178
# Epoch 4 completed in 3.35 seconds.
# Epoch 5/10000 - Train Loss: 0.7836, Val Loss: 1.2780, Val Acc: 0.5689
# Epoch 5 completed in 3.39 seconds.
# Epoch 6/10000 - Train Loss: 0.7148, Val Loss: 0.9794, Val Acc: 0.6857
# Epoch 6 completed in 3.36 seconds.
# Epoch 7/10000 - Train Loss: 0.6679, Val Loss: 0.8996, Val Acc: 0.6907
# Epoch 7 completed in 3.39 seconds.
# Epoch 8/10000 - Train Loss: 0.6386, Val Loss: 0.7786, Val Acc: 0.7564
# Epoch 8 completed in 3.38 seconds.
# Epoch 9/10000 - Train Loss: 0.6084, Val Loss: 0.9840, Val Acc: 0.6805
# Epoch 9 completed in 3.36 seconds.
# Epoch 10/10000 - Train Loss: 0.5884, Val Loss: 0.9299, Val Acc: 0.6881
# Epoch 10 completed in 3.39 seconds.
# Epoch 11/10000 - Train Loss: 0.5746, Val Loss: 0.6068, Val Acc: 0.8077
# Epoch 11 completed in 3.36 seconds.
# Epoch 12/10000 - Train Loss: 0.5599, Val Loss: 0.8474, Val Acc: 0.7266
# Epoch 12 completed in 3.38 seconds.
# Epoch 13/10000 - Train Loss: 0.5642, Val Loss: 0.6210, Val Acc: 0.7957
# Epoch 13 completed in 3.39 seconds.
# Epoch 14/10000 - Train Loss: 0.5441, Val Loss: 1.0519, Val Acc: 0.6795
# Epoch 14 completed in 3.39 seconds.
# Early stopping at epoch 15
# Finished training after 15 epochs!
# Finished training VGG15PlusPlus for 15 epochs
# VGG15PlusPlus - Test Accuracy: 62.69%, Training epochs: 15

# %%
def plot_loss_acc_x3(train_losses, val_losses, val_accs, epochs,
                     net_names=['VGG15PlusPlus', 'VGG15', 'VGG15Plus', 'VGG4Plus']):
    '''Makes a 3x1 plot of the training losses, val losses, and val accs for the 4 nets.

    This complete function is provided to you. Feel free to modify if necessary.

    Parameters:
    -----------
    train_losses: Python list of list. len(train_losses)=4.
        List of the training loss histories of the 4 nets.
    val_losses: Python list of list. len(val_losses)=4.
        List of the val loss histories of the 4 nets.
    val_accs: Python list of list. len(val_accs)=4.
        List of the val accuracy histories of the 4 nets.
    epochs: Python list of int. len(epochs)=4.
        The number of epochs used to train each network.
    net_names: Python list of str. len(epochs)=4.
        The string name of the networks. The order must correspond to the order of the loss and acc lists.
    '''
    fig, axes = plt.subplots(ncols=1, nrows=3, sharex=True, figsize=(5, 12))

    titles = ['CIFAR-10 Training Loss', 'CIFAR-10 Val Loss', 'CIFAR-10 Val Acc']
    xlabels = 3*['Epoch']
    data = [train_losses, val_losses, val_accs]

    for i in range(len(titles)):
        curr_hist = data[i]

        for n in range(len(net_names)):
            curr_data = np.copy(np.array(curr_hist[n]))

            if 'acc' in titles[i].lower():
                curr_data = 100*curr_data[:epochs[n]]

            axes[i].plot(curr_data, label=net_names[n])

        axes[i].set_xlabel(xlabels[i])
        # axes[i].set_ylabel(ylabels[i])
        axes[i].set_title(titles[i])

        if i == 0:
            axes[i].legend()

    plt.tight_layout()
    plt.show()

# %%
# Extract the results in the format needed for the plotting function
train_losses = [r["train_loss"] for r in results]
val_losses = [r["val_loss"] for r in results]
val_accs = [r["val_acc"] for r in results]
epochs_trained = [r["epochs"] for r in results]
net_names = [r["name"] for r in results]

# Call the plotting function
plot_loss_acc_x3(
    train_losses=train_losses,
    val_losses=val_losses,
    val_accs=val_accs,
    epochs=epochs_trained,
    net_names=net_names
)

# Print out final test accuracies for reference
print("\nFinal Test Accuracies:")
for r in results:
    print(f"{r['name']}: {r['test_acc']*100:.2f}%")
# Out:
# Final Test Accuracies:
# VGG4Plus: 68.82%
# VGG15: 78.95%
# VGG15Plus: 73.83%
# VGG15PlusPlus: 62.69%

# %% [markdown]
# ### 9e. Questions
#
# **Question 13** How does the runtime (per epoch) of the networks with batch normalization compare without it (e.g. `VGG15` vs. `VGG15Plus`)?

# %% [markdown]
# **Answer 13:**
# `VGG15` takes roughly 2.7s per epoch, while `VGG15Plus` takes roughly 3.3s per epoch, makes sense since the computation of the batch normalization increases the time.

# %% [markdown]
# ## Task 10. Learning rate decay
#
# The classification accuracy of the networks with batch normalization may seem a little underwhelming...but we can change that! A synergistic tool to potentially unlock improved classification accuracy is **learning rate decay.** We will adopt the simple approach of multiplicatively adjusting the learning rate. That is:
#
# $$
# \eta_{new} = d \times \eta_{curr}
# $$
#
# where $\eta$ is the learning rate and $d$ is a float between 0.0 and 1.0. This learning rate update does not occur on every epoch — it only gets applied when the validation loss stops improving for some number of epochs (i.e. the learning rate patience). This means we add and maintain an independent early stopping process dedicated to the learning rate.
#
# Let's add this to the training workflow then revisit the performance of the networks with batch normalization.

# %%
from vgg_nets import VGG15PlusPlus, VGG15, VGG15Plus, VGG4Plus

# %% [markdown]
# ### 10a. Add support for learning rate decay in `DeepNetwork`
#
# Follow the procedure outlined in class add learning rate decay to the training workflow. Here is a brief summary:
# 1. Implement `update_lr(lr_decay_rate)` to multiplicatively adjust the optimizer's learning rate.
# 2. In `fit`, create a separate new empty list before the training loop to represent the rolling validation loss related to the learning rate decay process.
# 3. In `fit`, adjacent to where you check early stopping for training epochs, check "early stopping" for learning rate. If "early stopping" is triggered for the learning rate, decrease the learning rate. Only decrease the learning rate a preset number of times (`lr_max_decays`).

# %%
from layers import Dense
from network import DeepNetwork

# %% [markdown]
# #### Test: Learning rate decay
#
# The following test trains a single layer softmax network on Iris. If everything is working as expected, you should see:
# - learning rate decays from 0.1 to 0.05 during epoch 6.
# - learning rate decays from 0.05 to 0.025 during epoch 25.
# - learning rate decays from 0.025 to 0.0125 during epoch 39.
# - learning rate decays from 0.0125 to 0.00625 during epoch 53.
# - training ends after 65 epochs.
#
# **Note:** If you do not get these exact results, that could be fine. What you are looking for is a drop in the learning rate when the val loss does not improve/decrease within a window of 3 epochs.

# %%
# Quickly make a mock network for testing
class SoftmaxNet(DeepNetwork):
    def __init__(self, input_feats_shape, C, reg=0):
        super().__init__(input_feats_shape, reg)
        self.output_layer = Dense('TestDense', units=C, activation='softmax', prev_layer_or_block=None)

    def __call__(self, x):
        return self.output_layer(x)

# Load in Iris train/validation sets
train_samps = tf.constant(np.load('data/iris/iris_train_samps.npy'), dtype=tf.float32)
train_labels = tf.constant(np.load('data/iris/iris_train_labels.npy'), dtype=tf.int32)
val_samps = tf.constant(np.load('data/iris/iris_val_samps.npy'), dtype=tf.float32)
val_labels = tf.constant(np.load('data/iris/iris_val_labels.npy'), dtype=tf.int32)

# Set some vars
C = 3
M = train_samps.shape[1]
mini_batch_sz = 25
lr = 1e-1
max_epochs = 5000
patience = 7
val_every = 1  # how often (in epochs) we check the val loss/acc/early stopping

# Create our test net
tf.random.set_seed(0)
slnet = SoftmaxNet((M,), C)
slnet.compile(lr=lr)

_, val_loss_hist, val_acc_hist, e = slnet.fit(train_samps, train_labels, val_samps, val_labels,
                                              batch_size=mini_batch_sz,
                                              max_epochs=max_epochs,
                                              patience=patience,
                                              val_every=val_every,
                                              lr_patience=3,
                                              lr_max_decays=4)

print(75*'-')
print(f'Iris test ended after {e} epochs with final val loss/acc of {val_loss_hist[-1]:.2f}/{val_acc_hist[-1]:.2f}')
print(75*'-')
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(TestDense) shape: [1, 3]
# ---------------------------------------------------------------------------
# Epoch 1/5000 - Train Loss: 1.2902, Val Loss: 0.7636, Val Acc: 0.6735
# Epoch 1 completed in 0.56 seconds.
# Epoch 2/5000 - Train Loss: 0.9263, Val Loss: 0.6645, Val Acc: 0.6531
# Epoch 2 completed in 0.01 seconds.
# Epoch 3/5000 - Train Loss: 0.6456, Val Loss: 0.5646, Val Acc: 0.6531
# Epoch 3 completed in 0.01 seconds.
# Epoch 4/5000 - Train Loss: 0.5560, Val Loss: 0.5184, Val Acc: 0.6735
# Epoch 4 completed in 0.01 seconds.
# Epoch 5/5000 - Train Loss: 0.4884, Val Loss: 0.4592, Val Acc: 0.6531
# Epoch 5 completed in 0.01 seconds.
# Epoch 6/5000 - Train Loss: 0.4455, Val Loss: 0.3904, Val Acc: 0.9388
# Epoch 6 completed in 0.01 seconds.
# Epoch 7/5000 - Train Loss: 0.4225, Val Loss: 0.3693, Val Acc: 0.9592
# Epoch 7 completed in 0.01 seconds.
# Epoch 8/5000 - Train Loss: 0.3922, Val Loss: 0.3635, Val Acc: 0.8367
# Epoch 8 completed in 0.01 seconds.
# Epoch 9/5000 - Train Loss: 0.3554, Val Loss: 0.3270, Val Acc: 0.9592
# Epoch 9 completed in 0.00 seconds.
# Epoch 10/5000 - Train Loss: 0.3619, Val Loss: 0.3123, Val Acc: 0.9796
# Epoch 10 completed in 0.01 seconds.
# Epoch 11/5000 - Train Loss: 0.3293, Val Loss: 0.3344, Val Acc: 0.8367
# Epoch 11 completed in 0.01 seconds.
# Epoch 12/5000 - Train Loss: 0.3106, Val Loss: 0.2861, Val Acc: 0.9796
# Epoch 12 completed in 0.01 seconds.
# Epoch 13/5000 - Train Loss: 0.3185, Val Loss: 0.2806, Val Acc: 0.9592
# Epoch 13 completed in 0.01 seconds.
# Epoch 14/5000 - Train Loss: 0.2873, Val Loss: 0.2784, Val Acc: 0.9388
# Epoch 14 completed in 0.01 seconds.
# Epoch 15/5000 - Train Loss: 0.2775, Val Loss: 0.2549, Val Acc: 0.9796
# Epoch 15 completed in 0.01 seconds.
# Epoch 16/5000 - Train Loss: 0.2693, Val Loss: 0.2536, Val Acc: 0.9592
# Epoch 16 completed in 0.01 seconds.
# Epoch 17/5000 - Train Loss: 0.2595, Val Loss: 0.2479, Val Acc: 0.9592
# Epoch 17 completed in 0.01 seconds.
# Epoch 18/5000 - Train Loss: 0.2483, Val Loss: 0.2295, Val Acc: 0.9796
# Epoch 18 completed in 0.01 seconds.
# Epoch 19/5000 - Train Loss: 0.2424, Val Loss: 0.2290, Val Acc: 0.9592
# Epoch 19 completed in 0.01 seconds.
# Epoch 20/5000 - Train Loss: 0.2484, Val Loss: 0.2333, Val Acc: 0.9592
# Epoch 20 completed in 0.01 seconds.
# Epoch 21/5000 - Train Loss: 0.2303, Val Loss: 0.2137, Val Acc: 0.9388
# Epoch 21 completed in 0.01 seconds.
# Epoch 22/5000 - Train Loss: 0.2309, Val Loss: 0.2153, Val Acc: 0.9592
# Epoch 22 completed in 0.01 seconds.
# Epoch 23/5000 - Train Loss: 0.2299, Val Loss: 0.2089, Val Acc: 0.9592
# Epoch 23 completed in 0.01 seconds.
# Epoch 24/5000 - Train Loss: 0.2058, Val Loss: 0.1925, Val Acc: 0.9796
# Epoch 24 completed in 0.01 seconds.
# Epoch 25/5000 - Train Loss: 0.2080, Val Loss: 0.1941, Val Acc: 0.9592
# Epoch 25 completed in 0.01 seconds.
# Epoch 26/5000 - Train Loss: 0.1991, Val Loss: 0.1906, Val Acc: 0.9592
# Epoch 26 completed in 0.01 seconds.
# Epoch 27/5000 - Train Loss: 0.1946, Val Loss: 0.1811, Val Acc: 0.9796
# Epoch 27 completed in 0.01 seconds.
# Epoch 28/5000 - Train Loss: 0.1955, Val Loss: 0.1775, Val Acc: 0.9592
# Epoch 28 completed in 0.01 seconds.
# Epoch 29/5000 - Train Loss: 0.1915, Val Loss: 0.1867, Val Acc: 0.9592
# Epoch 29 completed in 0.01 seconds.
# Epoch 30/5000 - Train Loss: 0.1843, Val Loss: 0.1675, Val Acc: 0.9796
# Epoch 30 completed in 0.01 seconds.
# Epoch 31/5000 - Train Loss: 0.1865, Val Loss: 0.1803, Val Acc: 0.9592
# Epoch 31 completed in 0.01 seconds.
# Epoch 32/5000 - Train Loss: 0.1775, Val Loss: 0.1614, Val Acc: 0.9796
# Epoch 32 completed in 0.01 seconds.
# Epoch 33/5000 - Train Loss: 0.1689, Val Loss: 0.1657, Val Acc: 0.9592
# Epoch 33 completed in 0.01 seconds.
# Epoch 34/5000 - Train Loss: 0.1764, Val Loss: 0.1568, Val Acc: 0.9796
# Epoch 34 completed in 0.01 seconds.
# Epoch 35/5000 - Train Loss: 0.1671, Val Loss: 0.1517, Val Acc: 0.9796
# Epoch 35 completed in 0.01 seconds.
# Epoch 36/5000 - Train Loss: 0.1596, Val Loss: 0.1671, Val Acc: 0.9592
# Epoch 36 completed in 0.01 seconds.
# Epoch 37/5000 - Train Loss: 0.1665, Val Loss: 0.1472, Val Acc: 0.9796
# Epoch 37 completed in 0.01 seconds.
# Epoch 38/5000 - Train Loss: 0.1572, Val Loss: 0.1568, Val Acc: 0.9592
# Epoch 38 completed in 0.01 seconds.
# Epoch 39/5000 - Train Loss: 0.1536, Val Loss: 0.1454, Val Acc: 0.9592
# Epoch 39 completed in 0.01 seconds.
# Epoch 40/5000 - Train Loss: 0.1495, Val Loss: 0.1456, Val Acc: 0.9592
# Epoch 40 completed in 0.01 seconds.
# Epoch 41/5000 - Train Loss: 0.1466, Val Loss: 0.1384, Val Acc: 0.9796
# Epoch 41 completed in 0.01 seconds.
# Epoch 42/5000 - Train Loss: 0.1446, Val Loss: 0.1378, Val Acc: 0.9796
# Epoch 42 completed in 0.01 seconds.
# Epoch 43/5000 - Train Loss: 0.1411, Val Loss: 0.1404, Val Acc: 0.9592
# Epoch 43 completed in 0.01 seconds.
# Epoch 44/5000 - Train Loss: 0.1394, Val Loss: 0.1349, Val Acc: 0.9592
# Epoch 44 completed in 0.01 seconds.
# Epoch 45/5000 - Train Loss: 0.1445, Val Loss: 0.1347, Val Acc: 0.9592
# Epoch 45 completed in 0.01 seconds.
# Epoch 46/5000 - Train Loss: 0.1544, Val Loss: 0.1464, Val Acc: 0.9592
# Epoch 46 completed in 0.01 seconds.
# Epoch 47/5000 - Train Loss: 0.1413, Val Loss: 0.1277, Val Acc: 0.9796
# Epoch 47 completed in 0.01 seconds.
# Epoch 48/5000 - Train Loss: 0.1360, Val Loss: 0.1500, Val Acc: 0.9592
# Epoch 48 completed in 0.01 seconds.
# Epoch 49/5000 - Train Loss: 0.1467, Val Loss: 0.1338, Val Acc: 0.9592
# Current lr= 0.1 Updated lr= 0.05
# Epoch 49 completed in 0.01 seconds.
# Epoch 50/5000 - Train Loss: 0.1369, Val Loss: 0.1242, Val Acc: 0.9592
# Epoch 50 completed in 0.01 seconds.
# Epoch 51/5000 - Train Loss: 0.1351, Val Loss: 0.1294, Val Acc: 0.9592
# Epoch 51 completed in 0.01 seconds.
# Epoch 52/5000 - Train Loss: 0.1280, Val Loss: 0.1363, Val Acc: 0.9592
# Current lr= 0.05 Updated lr= 0.025
# Epoch 52 completed in 0.01 seconds.
# Epoch 53/5000 - Train Loss: 0.1283, Val Loss: 0.1257, Val Acc: 0.9592
# Epoch 53 completed in 0.01 seconds.
# Epoch 54/5000 - Train Loss: 0.1247, Val Loss: 0.1231, Val Acc: 0.9796
# Epoch 54 completed in 0.01 seconds.
# Epoch 55/5000 - Train Loss: 0.1242, Val Loss: 0.1242, Val Acc: 0.9592
# Epoch 55 completed in 0.01 seconds.
# Epoch 56/5000 - Train Loss: 0.1236, Val Loss: 0.1258, Val Acc: 0.9592
# Current lr= 0.025 Updated lr= 0.0125
# Epoch 56 completed in 0.01 seconds.
# Epoch 57/5000 - Train Loss: 0.1230, Val Loss: 0.1253, Val Acc: 0.9592
# Current lr= 0.0125 Updated lr= 0.00625
# Epoch 57 completed in 0.01 seconds.
# Epoch 58/5000 - Train Loss: 0.1230, Val Loss: 0.1256, Val Acc: 0.9592
# Epoch 58 completed in 0.01 seconds.
# Epoch 59/5000 - Train Loss: 0.1231, Val Loss: 0.1259, Val Acc: 0.9592
# Epoch 59 completed in 0.01 seconds.
# Early stopping at epoch 60
# Finished training after 60 epochs!
# ---------------------------------------------------------------------------
# Iris test ended after 60 epochs with final val loss/acc of 0.12/0.96
# ---------------------------------------------------------------------------

# %% [markdown]
# ### 10b. Train VGG nets with batch normalization redux
#
# Repeat the training session you performed in the previous task involving the "plus networks" on CIFAR-10:
# - VGG4Plus
# - VGG15
# - VGG15Plus
# - VGG15PlusPlus
#
# Use default hyperparameters except:
# - Use AdamW optimizer.
# - Use He initialization
# - Use a patience of `15`.
# - Use a learning rate patience of 4.
#
# After training each net, store/record:
# 1. the network's final test accuracy.
# 2. the history of training loss (averaged across mini-batches, so one per epoch).
# 3. the history of validation loss (checked every epoch).
# 4. the history of validation accuracy (checked every epoch).
#
# **Notes:**
# - Set random seed before creating each net for consistency.
# - Use `tf.keras.backend.clear_session()` before creating each of the network to help prevent the memory used from growing.
#
# Training these networks should take a few hours. Your VGG15PlusPlus network should achieve the best results and shatter your previous CIFAR-10 val/test accuracy record by a substantial margin.

# %%
# Configure networks for training
networks = [
    {"name": "VGG4Plus", "model": VGG4Plus},
    {"name": "VGG15", "model": VGG15},
    {"name": "VGG15Plus", "model": VGG15Plus},
    {"name": "VGG15PlusPlus", "model": VGG15PlusPlus}
]

# Store results
results = []

# Train each network
for network in networks:
    print(f"\n=== Training {network['name']} ===")
    
    # Clear session and set seeds
    tf.keras.backend.clear_session()
    tf.random.set_seed(0)
    
    # Create model
    model = network["model"](C=10,input_feats_shape=(32, 32, 3),wt_init='he')
    
    # Compile with AdamW optimizer
    model.compile(optimizer='adamw', loss='cross_entropy')
    
    # Train with early stopping
    print(f"Starting training for {network['name']}...")
    train_loss_hist, val_loss_hist, val_acc_hist, epochs = model.fit(x_train,y_train,x_val,y_val,patience=15, lr_patience=4)
    print(f"Finished training {network['name']} for {epochs} epochs")
    
    # Evaluate on test set
    test_acc, test_loss = model.evaluate(x_test, y_test)
    
    # Store results
    results.append({
        "name": network["name"],
        "test_acc": test_acc.numpy(),
        "epochs": epochs,
        "train_loss": train_loss_hist,
        "val_loss": val_loss_hist,
        "val_acc": val_acc_hist
    })
    
    print(f"{network['name']} - Test Accuracy: {test_acc.numpy()*100:.2f}%, Training epochs: {epochs}")
# Out:
# === Training VGG4Plus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# Dropout layer output(Dropout) shape: [1, 128]
# Dense layer output(Dense_1) shape: [1, 128]
# Flatten layer output(Flatten) shape: [1, 16384]
# MaxPool2D layer output(MaxPool_1) shape: [1, 16, 16, 64]
# Conv2D layer output(Conv2D_2) shape: [1, 32, 32, 64]
# Conv2D layer output(Conv2D_1) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG4Plus...
# Epoch 1/10000 - Train Loss: 1.2989, Val Loss: 1.0847, Val Acc: 0.6252
# Epoch 1 completed in 7.28 seconds.
# Epoch 2/10000 - Train Loss: 0.9340, Val Loss: 0.9591, Val Acc: 0.6607
# Epoch 2 completed in 2.81 seconds.
# Epoch 3/10000 - Train Loss: 0.7795, Val Loss: 0.8948, Val Acc: 0.6961
# Epoch 3 completed in 2.69 seconds.
# Epoch 4/10000 - Train Loss: 0.6646, Val Loss: 1.0084, Val Acc: 0.6663
# Epoch 4 completed in 2.68 seconds.
# Epoch 5/10000 - Train Loss: 0.5550, Val Loss: 1.0864, Val Acc: 0.6707
# Epoch 5 completed in 2.75 seconds.
# Epoch 6/10000 - Train Loss: 0.4638, Val Loss: 1.0154, Val Acc: 0.6983
# Current lr= 0.001 Updated lr= 0.0005
# Epoch 6 completed in 2.83 seconds.
# Epoch 7/10000 - Train Loss: 0.3123, Val Loss: 0.9641, Val Acc: 0.7125
# Epoch 7 completed in 2.68 seconds.
# Epoch 8/10000 - Train Loss: 0.2476, Val Loss: 1.0441, Val Acc: 0.7208
# Epoch 8 completed in 2.65 seconds.
# Epoch 9/10000 - Train Loss: 0.2208, Val Loss: 1.1219, Val Acc: 0.7027
# Epoch 9 completed in 2.65 seconds.
# Epoch 10/10000 - Train Loss: 0.1948, Val Loss: 1.1358, Val Acc: 0.7139
# Current lr= 0.0005 Updated lr= 0.00025
# Epoch 10 completed in 2.65 seconds.
# Epoch 11/10000 - Train Loss: 0.1536, Val Loss: 1.1093, Val Acc: 0.7177
# Current lr= 0.00025 Updated lr= 0.000125
# Epoch 11 completed in 2.67 seconds.
# Epoch 12/10000 - Train Loss: 0.1171, Val Loss: 1.1166, Val Acc: 0.7250
# Epoch 12 completed in 2.65 seconds.
# Epoch 13/10000 - Train Loss: 0.1051, Val Loss: 1.1353, Val Acc: 0.7260
# Epoch 13 completed in 2.64 seconds.
# Epoch 14/10000 - Train Loss: 0.1009, Val Loss: 1.1589, Val Acc: 0.7224
# Current lr= 0.000125 Updated lr= 6.25e-05
# Epoch 14 completed in 2.60 seconds.
# Epoch 15/10000 - Train Loss: 0.0907, Val Loss: 1.1641, Val Acc: 0.7228
# Current lr= 6.25e-05 Updated lr= 3.125e-05
# Epoch 15 completed in 2.65 seconds.
# Epoch 16/10000 - Train Loss: 0.0833, Val Loss: 1.1682, Val Acc: 0.7274
# Current lr= 3.125e-05 Updated lr= 1.5625e-05
# Epoch 16 completed in 2.65 seconds.
# Early stopping at epoch 17
# Finished training after 17 epochs!
# Finished training VGG4Plus for 17 epochs
# VGG4Plus - Test Accuracy: 71.92%, Training epochs: 17
#
# === Training VGG15 ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15...
# Epoch 1/10000 - Train Loss: 1.9502, Val Loss: 1.5352, Val Acc: 0.4026
# Epoch 1 completed in 17.64 seconds.
# Epoch 2/10000 - Train Loss: 1.4796, Val Loss: 1.2708, Val Acc: 0.5469
# Epoch 2 completed in 11.82 seconds.
# Epoch 3/10000 - Train Loss: 1.1809, Val Loss: 1.1069, Val Acc: 0.5990
# Epoch 3 completed in 11.77 seconds.
# Epoch 4/10000 - Train Loss: 0.9869, Val Loss: 0.8745, Val Acc: 0.6917
# Epoch 4 completed in 11.73 seconds.
# Epoch 5/10000 - Train Loss: 0.8490, Val Loss: 0.8791, Val Acc: 0.7045
# Epoch 5 completed in 11.87 seconds.
# Epoch 6/10000 - Train Loss: 0.7619, Val Loss: 0.7448, Val Acc: 0.7572
# Epoch 6 completed in 11.66 seconds.
# Epoch 7/10000 - Train Loss: 0.7088, Val Loss: 0.6918, Val Acc: 0.7680
# Epoch 7 completed in 11.86 seconds.
# Epoch 8/10000 - Train Loss: 0.6374, Val Loss: 0.6776, Val Acc: 0.7835
# Epoch 8 completed in 11.91 seconds.
# Epoch 9/10000 - Train Loss: 0.6076, Val Loss: 0.6401, Val Acc: 0.7901
# Epoch 9 completed in 11.95 seconds.
# Epoch 10/10000 - Train Loss: 0.5711, Val Loss: 0.6757, Val Acc: 0.7821
# Epoch 10 completed in 11.85 seconds.
# Epoch 11/10000 - Train Loss: 0.5469, Val Loss: 0.6630, Val Acc: 0.7939
# Epoch 11 completed in 11.97 seconds.
# Epoch 12/10000 - Train Loss: 0.5255, Val Loss: 0.6429, Val Acc: 0.8013
# Current lr= 0.001 Updated lr= 0.0005
# Epoch 12 completed in 12.02 seconds.
# Epoch 13/10000 - Train Loss: 0.3322, Val Loss: 0.6242, Val Acc: 0.8195
# Epoch 13 completed in 11.66 seconds.
# Epoch 14/10000 - Train Loss: 0.2925, Val Loss: 0.6324, Val Acc: 0.8157
# Epoch 14 completed in 11.67 seconds.
# Epoch 15/10000 - Train Loss: 0.2683, Val Loss: 0.6440, Val Acc: 0.8229
# Epoch 15 completed in 11.64 seconds.
# Epoch 16/10000 - Train Loss: 0.2610, Val Loss: 0.6317, Val Acc: 0.8283
# Current lr= 0.0005 Updated lr= 0.00025
# Epoch 16 completed in 11.72 seconds.
# Epoch 17/10000 - Train Loss: 0.1285, Val Loss: 0.6238, Val Acc: 0.8486
# Epoch 17 completed in 11.75 seconds.
# Epoch 18/10000 - Train Loss: 0.0953, Val Loss: 0.7125, Val Acc: 0.8357
# Epoch 18 completed in 11.75 seconds.
# Epoch 19/10000 - Train Loss: 0.0917, Val Loss: 0.7292, Val Acc: 0.8415
# Epoch 19 completed in 11.80 seconds.
# Epoch 20/10000 - Train Loss: 0.0899, Val Loss: 0.7176, Val Acc: 0.8377
# Current lr= 0.00025 Updated lr= 0.000125
# Epoch 20 completed in 11.86 seconds.
# Epoch 21/10000 - Train Loss: 0.0306, Val Loss: 0.8719, Val Acc: 0.8470
# Current lr= 0.000125 Updated lr= 6.25e-05
# Epoch 21 completed in 10.84 seconds.
# Epoch 22/10000 - Train Loss: 0.0096, Val Loss: 0.8671, Val Acc: 0.8544
# Epoch 22 completed in 10.94 seconds.
# Epoch 23/10000 - Train Loss: 0.0051, Val Loss: 0.9506, Val Acc: 0.8572
# Current lr= 6.25e-05 Updated lr= 3.125e-05
# Epoch 23 completed in 11.07 seconds.
# Epoch 24/10000 - Train Loss: 0.0028, Val Loss: 0.9625, Val Acc: 0.8556
# Epoch 24 completed in 10.86 seconds.
# Epoch 25/10000 - Train Loss: 0.0021, Val Loss: 0.9913, Val Acc: 0.8582
# Current lr= 3.125e-05 Updated lr= 1.5625e-05
# Epoch 25 completed in 10.81 seconds.
# Epoch 26/10000 - Train Loss: 0.0018, Val Loss: 1.0044, Val Acc: 0.8576
# Current lr= 1.5625e-05 Updated lr= 7.8125e-06
# Epoch 26 completed in 11.28 seconds.
# Epoch 27/10000 - Train Loss: 0.0014, Val Loss: 1.0222, Val Acc: 0.8564
# Current lr= 7.8125e-06 Updated lr= 3.90625e-06
# Epoch 27 completed in 10.87 seconds.
# Epoch 28/10000 - Train Loss: 0.0014, Val Loss: 1.0324, Val Acc: 0.8564
# Current lr= 3.90625e-06 Updated lr= 1.953125e-06
# Epoch 28 completed in 10.89 seconds.
# Epoch 29/10000 - Train Loss: 0.0011, Val Loss: 1.0393, Val Acc: 0.8556
# Current lr= 1.953125e-06 Updated lr= 9.765625e-07
# Epoch 29 completed in 11.08 seconds.
# Epoch 30/10000 - Train Loss: 0.0010, Val Loss: 1.0408, Val Acc: 0.8562
# Current lr= 9.765625e-07 Updated lr= 4.882813e-07
# Epoch 30 completed in 10.90 seconds.
# Early stopping at epoch 31
# Finished training after 31 epochs!
# Finished training VGG15 for 31 epochs
# VGG15 - Test Accuracy: 85.25%, Training epochs: 31
#
# === Training VGG15Plus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15Plus...
# Epoch 1/10000 - Train Loss: 1.3617, Val Loss: 2.7453, Val Acc: 0.2528
# Epoch 1 completed in 27.30 seconds.
# Epoch 2/10000 - Train Loss: 0.8637, Val Loss: 1.1360, Val Acc: 0.6134
# Epoch 2 completed in 12.22 seconds.
# Epoch 3/10000 - Train Loss: 0.6902, Val Loss: 1.1892, Val Acc: 0.6026
# Epoch 3 completed in 12.46 seconds.
# Epoch 4/10000 - Train Loss: 0.5927, Val Loss: 1.2594, Val Acc: 0.6014
# Epoch 4 completed in 12.11 seconds.
# Epoch 5/10000 - Train Loss: 0.5197, Val Loss: 1.2749, Val Acc: 0.5954
# Current lr= 0.001 Updated lr= 0.0005
# Epoch 5 completed in 12.53 seconds.
# Epoch 6/10000 - Train Loss: 0.3356, Val Loss: 0.6801, Val Acc: 0.7718
# Epoch 6 completed in 11.98 seconds.
# Epoch 7/10000 - Train Loss: 0.2790, Val Loss: 0.6218, Val Acc: 0.7975
# Epoch 7 completed in 12.29 seconds.
# Epoch 8/10000 - Train Loss: 0.2528, Val Loss: 0.5563, Val Acc: 0.8213
# Epoch 8 completed in 12.44 seconds.
# Epoch 9/10000 - Train Loss: 0.2230, Val Loss: 0.6529, Val Acc: 0.7939
# Epoch 9 completed in 12.29 seconds.
# Epoch 10/10000 - Train Loss: 0.2011, Val Loss: 1.0340, Val Acc: 0.7035
# Epoch 10 completed in 12.03 seconds.
# Epoch 11/10000 - Train Loss: 0.1766, Val Loss: 0.7261, Val Acc: 0.7875
# Current lr= 0.0005 Updated lr= 0.00025
# Epoch 11 completed in 12.41 seconds.
# Epoch 12/10000 - Train Loss: 0.0711, Val Loss: 0.5609, Val Acc: 0.8444
# Epoch 12 completed in 12.18 seconds.
# Epoch 13/10000 - Train Loss: 0.0504, Val Loss: 0.6569, Val Acc: 0.8351
# Epoch 13 completed in 12.27 seconds.
# Epoch 14/10000 - Train Loss: 0.0609, Val Loss: 0.6662, Val Acc: 0.8283
# Epoch 14 completed in 12.04 seconds.
# Epoch 15/10000 - Train Loss: 0.0569, Val Loss: 0.5851, Val Acc: 0.8500
# Current lr= 0.00025 Updated lr= 0.000125
# Epoch 15 completed in 12.78 seconds.
# Epoch 16/10000 - Train Loss: 0.0206, Val Loss: 0.5011, Val Acc: 0.8810
# Epoch 16 completed in 13.00 seconds.
# Epoch 17/10000 - Train Loss: 0.0091, Val Loss: 0.5659, Val Acc: 0.8732
# Epoch 17 completed in 13.04 seconds.
# Epoch 18/10000 - Train Loss: 0.0136, Val Loss: 0.6492, Val Acc: 0.8566
# Epoch 18 completed in 12.73 seconds.
# Epoch 19/10000 - Train Loss: 0.0204, Val Loss: 0.6598, Val Acc: 0.8566
# Current lr= 0.000125 Updated lr= 6.25e-05
# Epoch 19 completed in 12.77 seconds.
# Epoch 20/10000 - Train Loss: 0.0080, Val Loss: 0.5357, Val Acc: 0.8856
# Epoch 20 completed in 12.68 seconds.
# Epoch 21/10000 - Train Loss: 0.0039, Val Loss: 0.5659, Val Acc: 0.8830
# Epoch 21 completed in 12.70 seconds.
# Epoch 22/10000 - Train Loss: 0.0034, Val Loss: 0.6257, Val Acc: 0.8780
# Epoch 22 completed in 12.92 seconds.
# Epoch 23/10000 - Train Loss: 0.0042, Val Loss: 0.6656, Val Acc: 0.8690
# Current lr= 6.25e-05 Updated lr= 3.125e-05
# Epoch 23 completed in 12.82 seconds.
# Epoch 24/10000 - Train Loss: 0.0032, Val Loss: 0.6158, Val Acc: 0.8832
# Current lr= 3.125e-05 Updated lr= 1.5625e-05
# Epoch 24 completed in 13.14 seconds.
# Epoch 25/10000 - Train Loss: 0.0022, Val Loss: 0.5998, Val Acc: 0.8816
# Epoch 25 completed in 12.90 seconds.
# Epoch 26/10000 - Train Loss: 0.0018, Val Loss: 0.5995, Val Acc: 0.8874
# Epoch 26 completed in 13.19 seconds.
# Epoch 27/10000 - Train Loss: 0.0017, Val Loss: 0.6017, Val Acc: 0.8878
# Epoch 27 completed in 13.18 seconds.
# Epoch 28/10000 - Train Loss: 0.0015, Val Loss: 0.6037, Val Acc: 0.8876
# Epoch 28 completed in 13.22 seconds.
# Epoch 29/10000 - Train Loss: 0.0014, Val Loss: 0.6126, Val Acc: 0.8876
# Current lr= 1.5625e-05 Updated lr= 7.8125e-06
# Epoch 29 completed in 13.28 seconds.
# Early stopping at epoch 30
# Finished training after 30 epochs!
# Finished training VGG15Plus for 30 epochs
# VGG15Plus - Test Accuracy: 88.48%, Training epochs: 30
#
# === Training VGG15PlusPlus ===
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Starting training for VGG15PlusPlus...
# Epoch 1/10000 - Train Loss: 1.6529, Val Loss: 2.3080, Val Acc: 0.3630
# Epoch 1 completed in 33.46 seconds.
# Epoch 2/10000 - Train Loss: 1.0993, Val Loss: 1.5228, Val Acc: 0.5188
# Epoch 2 completed in 13.43 seconds.
# Epoch 3/10000 - Train Loss: 0.9163, Val Loss: 1.7763, Val Acc: 0.4379
# Epoch 3 completed in 13.19 seconds.
# Epoch 4/10000 - Train Loss: 0.8151, Val Loss: 1.2927, Val Acc: 0.5569
# Epoch 4 completed in 12.52 seconds.
# Epoch 5/10000 - Train Loss: 0.7328, Val Loss: 1.5252, Val Acc: 0.5407
# Epoch 5 completed in 12.54 seconds.
# Epoch 6/10000 - Train Loss: 0.6732, Val Loss: 0.7694, Val Acc: 0.7552
# Epoch 6 completed in 12.50 seconds.
# Epoch 7/10000 - Train Loss: 0.6377, Val Loss: 0.9696, Val Acc: 0.6941
# Epoch 7 completed in 13.23 seconds.
# Epoch 8/10000 - Train Loss: 0.6112, Val Loss: 0.9274, Val Acc: 0.6951
# Epoch 8 completed in 12.71 seconds.
# Epoch 9/10000 - Train Loss: 0.5825, Val Loss: 1.0431, Val Acc: 0.6809
# Current lr= 0.001 Updated lr= 0.0005
# Epoch 9 completed in 12.86 seconds.
# Epoch 10/10000 - Train Loss: 0.4501, Val Loss: 0.8638, Val Acc: 0.7228
# Epoch 10 completed in 12.55 seconds.
# Epoch 11/10000 - Train Loss: 0.4038, Val Loss: 0.5720, Val Acc: 0.8099
# Epoch 11 completed in 13.30 seconds.
# Epoch 12/10000 - Train Loss: 0.3911, Val Loss: 0.5930, Val Acc: 0.8075
# Epoch 12 completed in 13.35 seconds.
# Epoch 13/10000 - Train Loss: 0.3720, Val Loss: 0.5691, Val Acc: 0.8117
# Epoch 13 completed in 13.78 seconds.
# Epoch 14/10000 - Train Loss: 0.3626, Val Loss: 0.5781, Val Acc: 0.8171
# Epoch 14 completed in 13.81 seconds.
# Epoch 15/10000 - Train Loss: 0.3546, Val Loss: 0.5634, Val Acc: 0.8219
# Epoch 15 completed in 13.55 seconds.
# Epoch 16/10000 - Train Loss: 0.3391, Val Loss: 0.6525, Val Acc: 0.7971
# Epoch 16 completed in 13.54 seconds.
# Epoch 17/10000 - Train Loss: 0.3308, Val Loss: 0.5745, Val Acc: 0.8207
# Epoch 17 completed in 13.70 seconds.
# Epoch 18/10000 - Train Loss: 0.3251, Val Loss: 0.6676, Val Acc: 0.7953
# Current lr= 0.0005 Updated lr= 0.00025
# Epoch 18 completed in 13.69 seconds.
# Epoch 19/10000 - Train Loss: 0.2257, Val Loss: 0.4122, Val Acc: 0.8704
# Epoch 19 completed in 13.71 seconds.
# Epoch 20/10000 - Train Loss: 0.1926, Val Loss: 0.4079, Val Acc: 0.8780
# Epoch 20 completed in 13.73 seconds.
# Epoch 21/10000 - Train Loss: 0.1899, Val Loss: 0.4793, Val Acc: 0.8612
# Epoch 21 completed in 13.16 seconds.
# Epoch 22/10000 - Train Loss: 0.1736, Val Loss: 0.4222, Val Acc: 0.8754
# Epoch 22 completed in 13.12 seconds.
# Epoch 23/10000 - Train Loss: 0.1728, Val Loss: 0.4076, Val Acc: 0.8804
# Epoch 23 completed in 13.02 seconds.
# Epoch 24/10000 - Train Loss: 0.1695, Val Loss: 0.5194, Val Acc: 0.8534
# Epoch 24 completed in 12.40 seconds.
# Epoch 25/10000 - Train Loss: 0.1637, Val Loss: 0.4843, Val Acc: 0.8688
# Epoch 25 completed in 12.90 seconds.
# Epoch 26/10000 - Train Loss: 0.1645, Val Loss: 0.4511, Val Acc: 0.8680
# Current lr= 0.00025 Updated lr= 0.000125
# Epoch 26 completed in 12.62 seconds.
# Epoch 27/10000 - Train Loss: 0.1020, Val Loss: 0.4325, Val Acc: 0.8838
# Epoch 27 completed in 12.68 seconds.
# Epoch 28/10000 - Train Loss: 0.0840, Val Loss: 0.4183, Val Acc: 0.8880
# Epoch 28 completed in 12.77 seconds.
# Epoch 29/10000 - Train Loss: 0.0814, Val Loss: 0.4062, Val Acc: 0.8968
# Epoch 29 completed in 12.93 seconds.
# Epoch 30/10000 - Train Loss: 0.0761, Val Loss: 0.4110, Val Acc: 0.8930
# Epoch 30 completed in 12.92 seconds.
# Epoch 31/10000 - Train Loss: 0.0752, Val Loss: 0.4443, Val Acc: 0.8832
# Epoch 31 completed in 12.82 seconds.
# Epoch 32/10000 - Train Loss: 0.0782, Val Loss: 0.4469, Val Acc: 0.8864
# Current lr= 0.000125 Updated lr= 6.25e-05
# Epoch 32 completed in 12.81 seconds.
# Epoch 33/10000 - Train Loss: 0.0522, Val Loss: 0.4135, Val Acc: 0.8976
# Current lr= 6.25e-05 Updated lr= 3.125e-05
# Epoch 33 completed in 12.85 seconds.
# Epoch 34/10000 - Train Loss: 0.0365, Val Loss: 0.4207, Val Acc: 0.8988
# Epoch 34 completed in 12.80 seconds.
# Epoch 35/10000 - Train Loss: 0.0316, Val Loss: 0.4572, Val Acc: 0.8928
# Epoch 35 completed in 12.84 seconds.
# Epoch 36/10000 - Train Loss: 0.0284, Val Loss: 0.4259, Val Acc: 0.9014
# Current lr= 3.125e-05 Updated lr= 1.5625e-05
# Epoch 36 completed in 12.83 seconds.
# Epoch 37/10000 - Train Loss: 0.0246, Val Loss: 0.4330, Val Acc: 0.9030
# Current lr= 1.5625e-05 Updated lr= 7.8125e-06
# Epoch 37 completed in 12.72 seconds.
# Epoch 38/10000 - Train Loss: 0.0215, Val Loss: 0.4355, Val Acc: 0.9038
# Epoch 38 completed in 12.69 seconds.
# Epoch 39/10000 - Train Loss: 0.0206, Val Loss: 0.4410, Val Acc: 0.9004
# Current lr= 7.8125e-06 Updated lr= 3.90625e-06
# Epoch 39 completed in 12.70 seconds.
# Epoch 40/10000 - Train Loss: 0.0206, Val Loss: 0.4330, Val Acc: 0.9052
# Current lr= 3.90625e-06 Updated lr= 1.953125e-06
# Epoch 40 completed in 12.74 seconds.
# Epoch 41/10000 - Train Loss: 0.0202, Val Loss: 0.4329, Val Acc: 0.9052
# Epoch 41 completed in 12.54 seconds.
# Epoch 42/10000 - Train Loss: 0.0189, Val Loss: 0.4325, Val Acc: 0.9044
# Epoch 42 completed in 12.49 seconds.
# Early stopping at epoch 43
# Finished training after 43 epochs!
# Finished training VGG15PlusPlus for 43 epochs
# VGG15PlusPlus - Test Accuracy: 89.79%, Training epochs: 43

# %% [markdown]
# Adapt the following code to plot your findings. `plot_loss_acc_x3` is defined in the previous task above.

# %%
train_losses_bn = [r["train_loss"] for r in results]
val_losses_bn = [r["val_loss"] for r in results]
val_accs_bn = [r["val_acc"] for r in results]
epochs_bn = [r["epochs"] for r in results]
accs_bn = [r["test_acc"] for r in results]
net_names = [r["name"] for r in results]


plot_loss_acc_x3(train_losses_bn, val_losses_bn, val_accs_bn, epochs_bn, net_names)

print('CIFAR-10 test accuracy:')
for i in range(len(net_names)):
    print(f'{net_names[i]}: {100*accs_bn[i]:.2f}%')
# Out:
# CIFAR-10 test accuracy:
# VGG4Plus: 71.92%
# VGG15: 85.25%
# VGG15Plus: 88.48%
# VGG15PlusPlus: 89.79%

# %% [markdown]
# ### 10c. Questions
#
# **Question 14** What did the results of this experiment reveal about the relationship about network depth/size and classification accuracy? Please be specific.
#
# **Question 15** Are there any downsides to the highest performing network (or is it just totally awesome :)?

# %% [markdown]
# **Answer 14:** The deeper the network goes, the better it tends to perform. The final results showed a positive association between network depth and accuracy, with VGG4Plus performing the worst by far (~72%), with a vast jump to VGG15 (~85%) and increases becoming more diminishing between the varying versions of VGG15, but show no regression - VGG15PlusPlus wins at ~90%!
#
# **Answer 15:** Took longer to train per epoch, and more total epochs.

# %% [markdown]
# ## Extensions
#
# ### General guidelines
#
# 1. Never integrate extensions into your base project so that they change the expected behavior of core functions. If your extension changes the core design/behavior, no problem, duplicate your working base project and add features from there.
# 2. Check the rubric to keep in mind how extensions on this project will be graded.
# 3. While I may consult your code and "written log" of what you did, **I am grading your extensions based on what you present in your 3-5 min video.**
# 3. I suggest documenting your explorations in a "log" or "lab notebook" style (i.e. documenting your thought/progression/discovery/learning process). I'm not grading your writing, so you can keep it succinct. **Whatever is most useful to you to remember what you did.**
# 4. I suggest taking a hypothesis driven approach. For example "I was curious about X so I explored Y. I found Z, which was not what I expected because..., so then tried A..."
# 5. Make plots to help showcase your results.
# 6. **More is not necessarily better.** Generally, a small number of "in-depth" extensions count for more than many "shallow" extensions.
#
# ### AI guidelines
#
# You may use AI in mostly any capacity for extensions. However, keep in mind:
# 1. There is no need to use AI at all!
# 2. You are welcome to use AI as a tool (e.g. automate something that is tedious, help you get unstuck, etc.). However, you should be coding, you should be thinking, you should be writing, you should be creating. If you are spending most (or even close to most) of your time typing into a chatbot and copy-pasting, you have probably gone too far with AI use.
# 3. I don't find large volumes of AI generated code/text/plots to be particularly impressive and you risk losing my interest while grading. Remember: I'm grading your extensions based on your video presentation. **More is not necessarily better.**
#
# ### Video guidelines
#
# 1. Please try to keep your video to 5 minutes (*I have other projects to grade!*). If you turn in a longer video, I make no promise that I will watch more than 5 minutes.
# 2. Your screen should be shared as you show me what you did. A live video of your face should also appear somewhere on the screen (e.g. picture-in-picture overlay / split screen).
# 3. Your partner should join you for the video and take turns talking, but, if necessary, it is fine to have one team member present during the record the video.
# 4. Do not simply read text from your notebook, do not read from a prepared script. I am not grading how polished your video presentation is (see extension grading criteria on rubric).
# 5. I am looking for original and creative explorations sparked by your curiosity/interest/passion in a topic. This should be apparent in your video.
# 6. Be natural,, don't feel the need to impress me with fancy language. If it is helpful, imagine that we are talking one-on-one about your extension. Tell me what you did :)
#
# ### Extension ideas

# %% [markdown]
# #### 1. Super Resolution Convolutional Neural Network
#
# or SRCNN for short

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import time
import network
import layers as ly
from datasets import get_dataset

tf.random.set_seed(0)
tf.keras.backend.clear_session()

class SRCNN(network.DeepNetwork):
    def __init__(self, input_feats_shape, wt_init='he', reg=0):
        super().__init__(input_feats_shape, reg)
        self.conv1 = ly.Conv2D('Conv1', 64, (9, 9), wt_init=wt_init, 
                               activation='relu', do_batch_norm=False)
        self.conv2 = ly.Conv2D('Conv2', 32, (1, 1), wt_init=wt_init, 
                               activation='relu', do_batch_norm=False)
        self.output_layer = ly.Conv2D('Conv3', 3, (5, 5), wt_init=wt_init, 
                                      activation='linear', do_batch_norm=False)

    # Override default loss so it doesn’t attempt classification
    def loss(self, out_net_act, y, eps=1e-9):
        return tf.reduce_mean(tf.square(out_net_act - y))

    def __call__(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.output_layer(x)
        return x


def preprocess_image(hr_image, scale_factor=2):
    """
    Given a high-resolution image, simulate a low-resolution image by first downscaling
    (using area interpolation) and then upscaling back to original size using bicubic interpolation.
    """
    hr = tf.convert_to_tensor(hr_image, dtype=tf.float32)
    # Downscale (e.g., from 32x32 to 16x16)
    new_size = (hr.shape[0] // scale_factor, hr.shape[1] // scale_factor)
    lr = tf.image.resize(hr, new_size, method='area')
    # Upscale back to original size using bicubic interpolation
    lr_up = tf.image.resize(lr, (hr.shape[0], hr.shape[1]), method=tf.image.ResizeMethod.BICUBIC)
    return lr_up, hr

def create_superres_dataset(x, scale_factor=2):
    """
    Converts a dataset of high-res images into a pair of images:
    - A bicubic-upsampled (low-res) image.
    - The original high-res image.
    """
    bicubic_list = []
    hr_list = []
    for img in x:
        lr_up, hr = preprocess_image(img, scale_factor)
        bicubic_list.append(lr_up)
        hr_list.append(hr)
    return tf.stack(bicubic_list), tf.stack(hr_list)


x_train, y_train, x_val, y_val, x_test, y_test, classnames = get_dataset('cifar10', standardize_ds=False, val_prop=0.1)

# For our super resolution task we ignore the labels.
X_train, Y_train = create_superres_dataset(x_train, scale_factor=2)
X_test, Y_test = create_superres_dataset(x_test, scale_factor=2)
# Out:
# 2025-03-14 22:22:03.628808: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-14 22:22:03.640480: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742005323.653450   29248 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742005323.657062   29248 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-14 22:22:03.669248: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# I0000 00:00:1742005327.008991   29248 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5564 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
tf.random.set_seed(0)
tf.keras.backend.clear_session()



input_shape = (X_train.shape[1:] ) # e.g., (32, 32, 3)
model = SRCNN(input_feats_shape=input_shape, wt_init='he', reg=0)


model.compile(loss="mse", optimizer="adam", lr=1e-4, beta_1=0.9, print_summary=True)


x = X_train
y = Y_train

N = x.shape[0]
indices = np.arange(N)
rng = np.random.default_rng(0)  # Fixed random seed for reproducibility
max_epochs = 100
batch_size = 64
train_loss_hist = []

for e in range(1, max_epochs + 1):
    start_time = time.time()
    rng.shuffle(indices)
    
    epoch_loss = []
    # Mini-batch training loop using tf.gather
    for i in range(0, N, batch_size):
        batch_indices = indices[i:i + batch_size]
        x_batch = tf.gather(x, batch_indices)
        y_batch = tf.gather(y, batch_indices)
        
        # Use your network's train_step method
        loss = model.train_step(x_batch, y_batch)
        epoch_loss.append(loss.numpy())
    
    avg_train_loss = np.mean(epoch_loss)
    train_loss_hist.append(avg_train_loss)
    print(f"Epoch {e}/{max_epochs} - Train Loss: {avg_train_loss:.4f} - Time: {time.time() - start_time:.2f}s")



N_test = X_test.shape[0]
indices_test = np.arange(N_test)
test_losses = []

for i in range(0, N_test, batch_size):
    batch_indices = indices_test[i:i + batch_size]
    x_batch = tf.gather(X_test, batch_indices)
    y_batch = tf.gather(Y_test, batch_indices)
    
    out_net_act = model(x_batch)
    loss = model.loss(out_net_act, y_batch)
    test_losses.append(loss.numpy())

avg_test_loss = np.mean(test_losses)
print(f"Test Loss: {avg_test_loss:.4f}")



num_examples = 10
indices = np.random.choice(X_test.shape[0], num_examples, replace=False)

# Adjust the figure size to be smaller
fig, axes = plt.subplots(num_examples, 3, figsize=(10, 2*num_examples))
titles = ['Bicubic Input', 'SRCNN Output', 'Original High-Res']

for i, idx in enumerate(indices):
    input_img = X_test[idx].numpy()
    original_img = Y_test[idx].numpy()
    # Run SRCNN on a single image (adding batch dimension)
    sr_img = model(tf.expand_dims(input_img, axis=0))[0].numpy()
    
    for j, img in enumerate([input_img, sr_img, original_img]):
        ax = axes[i, j] if num_examples > 1 else axes[j]
        ax.imshow(np.clip(img, 0, 1))
        ax.set_title(titles[j])
        ax.axis('off')

plt.tight_layout()
plt.show()
plt.tight_layout()
plt.show()
# Out:
# I0000 00:00:1742005401.646608   29248 cuda_dnn.cc:529] Loaded cuDNN version 90300
# ---------------------------------------------------------------------------
# Conv2D layer output(Conv3) shape: [1, 32, 32, 3]
# ---------------------------------------------------------------------------
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742005402.213883   29248 service.cc:148] XLA service 0x336d6ab0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1742005402.213919   29248 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2025-03-14 22:23:22.222164: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1742005402.818081   29248 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1/100 - Train Loss: 0.0744 - Time: 2.93s
# Epoch 2/100 - Train Loss: 0.0149 - Time: 2.04s
# Epoch 3/100 - Train Loss: 0.0107 - Time: 2.01s
# Epoch 4/100 - Train Loss: 0.0087 - Time: 1.84s
# Epoch 5/100 - Train Loss: 0.0075 - Time: 1.92s
# Epoch 6/100 - Train Loss: 0.0068 - Time: 1.80s
# Epoch 7/100 - Train Loss: 0.0062 - Time: 1.71s
# Epoch 8/100 - Train Loss: 0.0058 - Time: 1.74s
# Epoch 9/100 - Train Loss: 0.0056 - Time: 1.64s
# Epoch 10/100 - Train Loss: 0.0053 - Time: 1.79s
# Epoch 11/100 - Train Loss: 0.0052 - Time: 1.89s
# Epoch 12/100 - Train Loss: 0.0050 - Time: 1.89s
# Epoch 13/100 - Train Loss: 0.0049 - Time: 1.81s
# Epoch 14/100 - Train Loss: 0.0048 - Time: 1.68s
# Epoch 15/100 - Train Loss: 0.0048 - Time: 1.52s
# Epoch 16/100 - Train Loss: 0.0047 - Time: 1.51s
# Epoch 17/100 - Train Loss: 0.0047 - Time: 1.50s
# Epoch 18/100 - Train Loss: 0.0046 - Time: 1.48s
# Epoch 19/100 - Train Loss: 0.0046 - Time: 1.47s
# Epoch 20/100 - Train Loss: 0.0046 - Time: 1.46s
# Epoch 21/100 - Train Loss: 0.0046 - Time: 1.46s
# Epoch 22/100 - Train Loss: 0.0045 - Time: 1.47s
# Epoch 23/100 - Train Loss: 0.0045 - Time: 1.47s
# Epoch 24/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 25/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 26/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 27/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 28/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 29/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 30/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 31/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 32/100 - Train Loss: 0.0045 - Time: 1.47s
# Epoch 33/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 34/100 - Train Loss: 0.0045 - Time: 1.45s
# Epoch 35/100 - Train Loss: 0.0045 - Time: 1.48s
# Epoch 36/100 - Train Loss: 0.0045 - Time: 1.46s
# Epoch 37/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 38/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 39/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 40/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 41/100 - Train Loss: 0.0044 - Time: 1.50s
# Epoch 42/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 43/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 44/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 45/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 46/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 47/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 48/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 49/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 50/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 51/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 52/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 53/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 54/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 55/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 56/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 57/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 58/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 59/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 60/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 61/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 62/100 - Train Loss: 0.0044 - Time: 1.46s
# Epoch 63/100 - Train Loss: 0.0044 - Time: 1.47s
# Epoch 64/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 65/100 - Train Loss: 0.0044 - Time: 1.45s
# Epoch 66/100 - Train Loss: 0.0044 - Time: 1.48s
# Epoch 67/100 - Train Loss: 0.0044 - Time: 1.67s
# Epoch 68/100 - Train Loss: 0.0044 - Time: 1.66s
# Epoch 69/100 - Train Loss: 0.0044 - Time: 1.81s
# Epoch 70/100 - Train Loss: 0.0044 - Time: 1.83s
# Epoch 71/100 - Train Loss: 0.0044 - Time: 1.82s
# Epoch 72/100 - Train Loss: 0.0044 - Time: 1.84s
# Epoch 73/100 - Train Loss: 0.0044 - Time: 1.88s
# Epoch 74/100 - Train Loss: 0.0044 - Time: 1.74s
# Epoch 75/100 - Train Loss: 0.0044 - Time: 1.86s
# Epoch 76/100 - Train Loss: 0.0044 - Time: 1.77s
# Epoch 77/100 - Train Loss: 0.0044 - Time: 1.86s
# Epoch 78/100 - Train Loss: 0.0044 - Time: 1.76s
# Epoch 79/100 - Train Loss: 0.0044 - Time: 1.82s
# Epoch 80/100 - Train Loss: 0.0044 - Time: 1.81s
# Epoch 81/100 - Train Loss: 0.0044 - Time: 1.83s
# Epoch 82/100 - Train Loss: 0.0044 - Time: 1.82s
# Epoch 83/100 - Train Loss: 0.0044 - Time: 1.82s
# Epoch 84/100 - Train Loss: 0.0044 - Time: 1.81s
# Epoch 85/100 - Train Loss: 0.0044 - Time: 1.85s
# Epoch 86/100 - Train Loss: 0.0044 - Time: 1.78s
# Epoch 87/100 - Train Loss: 0.0044 - Time: 1.77s
# Epoch 88/100 - Train Loss: 0.0044 - Time: 1.79s
# Epoch 89/100 - Train Loss: 0.0044 - Time: 1.79s
# Epoch 90/100 - Train Loss: 0.0044 - Time: 1.76s
# Epoch 91/100 - Train Loss: 0.0044 - Time: 1.68s
# Epoch 92/100 - Train Loss: 0.0044 - Time: 1.58s
# Epoch 93/100 - Train Loss: 0.0044 - Time: 1.59s
# Epoch 94/100 - Train Loss: 0.0044 - Time: 1.58s
# Epoch 95/100 - Train Loss: 0.0044 - Time: 1.60s
# Epoch 96/100 - Train Loss: 0.0044 - Time: 1.59s
# Epoch 97/100 - Train Loss: 0.0044 - Time: 1.56s
# Epoch 98/100 - Train Loss: 0.0044 - Time: 1.58s
# Epoch 99/100 - Train Loss: 0.0044 - Time: 1.59s
# Epoch 100/100 - Train Loss: 0.0044 - Time: 1.59s
# Test Loss: 0.0044

# %% [markdown]
# #### 2. Other image datasets
#
# You now have a family of fast, high performing neural networks ranging in size. Apply them to another dataset of your choice.

# %% [markdown]
# #### 3. AlexNet
#
# Research the original AlexNet architecture and create a network that implements it. *You may have to ignore a few "hacks" Krizhevsky and colleagues had to perform — as pioneers, they were operating at the absolute limit of what GPUs of the day could do!*

# %%
from datasets import get_dataset
from alexnet import AlexNet

x_train, y_train, x_val, y_val, x_test, y_test, classnames = get_dataset("cifar10")

tf.random.set_seed(0)
tf.keras.backend.clear_session()

# Create model
model = AlexNet(C=10,input_feats_shape=(32, 32, 3),wt_init='he')
model.compile(optimizer='adam', loss='cross_entropy', lr=1e-5)
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(output) shape: [1, 10]
# Dropout layer output(dropout_2) shape: [1, 4096]
# Dense layer output(dense_2) shape: [1, 4096]
# Dropout layer output(dropout_1) shape: [1, 4096]
# Dense layer output(dense_1) shape: [1, 4096]
# Flatten layer output(flatten) shape: [1, 0]
# MaxPool2D layer output(pool_3) shape: [1, 0, 0, 256]
# Conv2D layer output(conv_5) shape: [1, 1, 1, 256]
# Conv2D layer output(conv_4) shape: [1, 1, 1, 384]
# Conv2D layer output(conv_3) shape: [1, 1, 1, 384]
# MaxPool2D layer output(pool_2) shape: [1, 1, 1, 256]
# Conv2D layer output(conv_2) shape: [1, 3, 3, 256]
# MaxPool2D layer output(pool_1) shape: [1, 3, 3, 96]
# Conv2D layer output(conv_1) shape: [1, 8, 8, 96]
# ---------------------------------------------------------------------------

# %% [markdown]
# The original AlexNet architecture is:
# ```
# conv1: 96 filters, 11x11 kernel, stride=4
# pool1: 3x3 kernel, stride=2
# conv2: 256 filters, 5x5 kernel, stride=1
# pool2: 3x3 kernel, stride=2
# conv3: 384 filters, 3x3 kernel, stride=1
# conv4: 384 filters, 3x3 kernel, stride=1
# conv5: 256 filters, 3x3 kernel, stride=1
# maxpool1: 3x3 kernel, stride=2
# flatten
# dense1: 4096 units
# dropout
# dense2: 4096 units
# dropout
# output
# ```
#
# Unfortunately, the original AlexNet architecture is not very well suited for CIFAR-10 since the images are so small. As we can see above, after the second maxpool layer, the spatial dimensions of the image are reduced to 1x1. After the third maxpool layer, the spatial dimensions are reduced to 0x0 and the code crashes.
#
# We've adapted AlexNet (inspired by the CS343 modified AlexNet) to work with CIFAR-10. The adapted architecture is:
# ```
# conv1: 96 filters, 7x7 kernel, stride=2
# pool1: 2x2 kernel, stride=2, padding=valid
# conv2: 256 filters, 5x5 kernel, stride=1
# pool2: 2x2 kernel, stride=2, padding=valid
# conv3: 384 filters, 3x3 kernel, stride=1
# conv4: 384 filters, 3x3 kernel, stride=1
# conv5: 256 filters, 3x3 kernel, stride=1
# maxpool1: 2x2 kernel, stride=2, padding=valid
# flatten
# dense1: 2048 units
# dropout
# dense2: 1024 units
# dropout
# output
# ```
# We have also added batch normalization to the conv and dense layers in the adapted AlexNet architecture.
#
# With this adapted architecture, we get a test accuracy of 70.3% after 10 epochs.

# %%
from datasets import get_dataset
from alexnet import MiniAlexNet

x_train, y_train, x_val, y_val, x_test, y_test, classnames = get_dataset("cifar10")

tf.random.set_seed(0)
tf.keras.backend.clear_session()

# Create model
model = MiniAlexNet(C=10,input_feats_shape=(32, 32, 3),wt_init='he')
model.compile(optimizer='adam', loss='cross_entropy', lr=1e-3)

# Train with early stopping
train_loss_hist, val_loss_hist, val_acc_hist, epochs = model.fit(x_train,y_train,x_val,y_val,patience=5,max_epochs=25)
print(f"Finished training AlexNet for {epochs} epochs")

# Evaluate on test set
test_acc, test_loss = model.evaluate(x_test, y_test)
print(f"AlexNet test acc: {test_acc.numpy()*100:.2f}")
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(output) shape: [1, 10]
# Dropout layer output(dropout_2) shape: [1, 1024]
# Dense layer output(dense_2) shape: [1, 1024]
# Dropout layer output(dropout_1) shape: [1, 2048]
# Dense layer output(dense_1) shape: [1, 2048]
# Flatten layer output(flatten) shape: [1, 1024]
# MaxPool2D layer output(pool_3) shape: [1, 2, 2, 256]
# Conv2D layer output(conv_5) shape: [1, 4, 4, 256]
# Conv2D layer output(conv_4) shape: [1, 4, 4, 384]
# Conv2D layer output(conv_3) shape: [1, 4, 4, 384]
# MaxPool2D layer output(pool_2) shape: [1, 4, 4, 256]
# Conv2D layer output(conv_2) shape: [1, 8, 8, 256]
# MaxPool2D layer output(pool_1) shape: [1, 8, 8, 96]
# Conv2D layer output(conv_1) shape: [1, 16, 16, 96]
# ---------------------------------------------------------------------------
# Epoch 1/25 - Train Loss: 1.4648, Val Loss: 1.4636, Val Acc: 0.5282
# Epoch 1 completed in 6.98 seconds.
# Epoch 2/25 - Train Loss: 1.0145, Val Loss: 1.0448, Val Acc: 0.6446
# Epoch 2 completed in 1.14 seconds.
# Epoch 3/25 - Train Loss: 0.8156, Val Loss: 1.0138, Val Acc: 0.6605
# Epoch 3 completed in 1.13 seconds.
# Epoch 4/25 - Train Loss: 0.6829, Val Loss: 0.9454, Val Acc: 0.6841
# Epoch 4 completed in 1.14 seconds.
# Epoch 5/25 - Train Loss: 0.5589, Val Loss: 0.9204, Val Acc: 0.7015
# Epoch 5 completed in 1.13 seconds.
# Epoch 6/25 - Train Loss: 0.4561, Val Loss: 0.8536, Val Acc: 0.7264
# Epoch 6 completed in 1.14 seconds.
# Epoch 7/25 - Train Loss: 0.3581, Val Loss: 1.0339, Val Acc: 0.6943
# Epoch 7 completed in 1.13 seconds.
# Epoch 8/25 - Train Loss: 0.2889, Val Loss: 1.0489, Val Acc: 0.7141
# Epoch 8 completed in 1.13 seconds.
# Epoch 9/25 - Train Loss: 0.2219, Val Loss: 1.1019, Val Acc: 0.7113
# Epoch 9 completed in 1.13 seconds.
# Early stopping at epoch 10
# Finished training after 10 epochs!
# Finished training AlexNet for 10 epochs
# AlexNet test acc: 70.36

# %% [markdown]
# #### 4. Add support for saving/loading network weights
#
# A key limitation of your current deep learning library is that parameters that capture the learning in networks are completely reset/lost/wiped out when the notebook kernel is terminated. Add (and test!) support for saving network parameters to disk after (or periodically during) training. Add (and test!) support for loading network parameters back into the network from disk before training.
#
# Be careful to include the moving mean and standard deviation parameters in batch normalization layers otherwise the whole net will not work!

# %% [markdown]
# For this extension, we have added the ability to load and save weights, added as additional methods in the `DeepNetwork` class. The methods are `load_weights` and `save_weights`. The weights are saved in a dictionary, in `npy` format.

# %%
tf.random.set_seed(0)
tf.keras.backend.clear_session()

# Create and compile model with dropout
model = VGG15PlusPlus(C=10, input_feats_shape=(32, 32, 3), wt_init='he')
model.compile(optimizer='adamw', lr=1e-3)

# Train model
train_loss_hist, val_loss_hist, val_acc_hist, epochs = model.fit(x_train, y_train, x_val, y_val, patience=3, max_epochs=10)
print(f"Finished training VGG15 for {epochs} epochs")

# Evaluate on test set
test_acc, test_loss = model.evaluate(x_test, y_test)
print(f"VGG15 test acc: {test_acc.numpy()*100:.2f}%")

# Save the model
model.save_weights('vgg15_weights.npy')
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# Epoch 1/10 - Train Loss: 1.8692, Val Loss: 2.1817, Val Acc: 0.3241
# Epoch 1 completed in 14.04 seconds.
# Epoch 2/10 - Train Loss: 1.2417, Val Loss: 1.2534, Val Acc: 0.5715
# Epoch 2 completed in 3.41 seconds.
# Epoch 3/10 - Train Loss: 0.9898, Val Loss: 1.2302, Val Acc: 0.5659
# Epoch 3 completed in 3.38 seconds.
# Epoch 4/10 - Train Loss: 0.8588, Val Loss: 1.2318, Val Acc: 0.5779
# Epoch 4 completed in 3.39 seconds.
# Epoch 5/10 - Train Loss: 0.7802, Val Loss: 1.1393, Val Acc: 0.6334
# Epoch 5 completed in 3.38 seconds.
# Epoch 6/10 - Train Loss: 0.7131, Val Loss: 0.9367, Val Acc: 0.6953
# Epoch 6 completed in 3.37 seconds.
# Epoch 7/10 - Train Loss: 0.6606, Val Loss: 0.8809, Val Acc: 0.7027
# Epoch 7 completed in 3.37 seconds.
# Epoch 8/10 - Train Loss: 0.6344, Val Loss: 0.8226, Val Acc: 0.7330
# Epoch 8 completed in 3.37 seconds.
# Epoch 9/10 - Train Loss: 0.6057, Val Loss: 0.8626, Val Acc: 0.7188
# Epoch 9 completed in 3.36 seconds.
# Epoch 10/10 - Train Loss: 0.5849, Val Loss: 0.7239, Val Acc: 0.7676
# Epoch 10 completed in 3.37 seconds.
# Finished training after 10 epochs!
# Finished training VGG15 for 10 epochs
# VGG15 test acc: 76.22%
# Network weights saved to vgg15_weights.npy

# %%
tf.random.set_seed(0)
tf.keras.backend.clear_session()

model2 = VGG15PlusPlus(C=10, input_feats_shape=(32, 32, 3), wt_init='he')
model2.compile(optimizer='adamw', lr=1e-5)

# Evaluate the model before loading weights
test_acc, test_loss = model2.evaluate(x_test, y_test)
print(f"VGG15 test acc before loading weights: {test_acc.numpy()*100:.2f}%")

# Load the weights into the new model
model2.load_weights('vgg15_weights.npy')
test_acc, test_loss = model2.evaluate(x_test, y_test)
print(f"VGG15 test acc after loading weights: {test_acc.numpy()*100:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# Dense layer output(Output) shape: [1, 10]
# DenseBlock1:
# 	Dropout layer output(DenseBlock1/dropout_0) shape: [1, 512]
# 	Dense layer output(DenseBlock1/dense_0) shape: [1, 512]
# Flatten layer output(Flatten) shape: [1, 512]
# ConvBlock5:
# 	Dropout layer output(ConvBlock5/dropout) shape: [1, 1, 1, 512]
# 	MaxPool2D layer output(ConvBlock5/maxpool) shape: [1, 1, 1, 512]
# 	Conv2D layer output(ConvBlock5/conv_2) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_1) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock5/conv_0) shape: [1, 2, 2, 512]
# ConvBlock4:
# 	Dropout layer output(ConvBlock4/dropout) shape: [1, 2, 2, 512]
# 	MaxPool2D layer output(ConvBlock4/maxpool) shape: [1, 2, 2, 512]
# 	Conv2D layer output(ConvBlock4/conv_2) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_1) shape: [1, 4, 4, 512]
# 	Conv2D layer output(ConvBlock4/conv_0) shape: [1, 4, 4, 512]
# ConvBlock3:
# 	Dropout layer output(ConvBlock3/dropout) shape: [1, 4, 4, 256]
# 	MaxPool2D layer output(ConvBlock3/maxpool) shape: [1, 4, 4, 256]
# 	Conv2D layer output(ConvBlock3/conv_2) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_1) shape: [1, 8, 8, 256]
# 	Conv2D layer output(ConvBlock3/conv_0) shape: [1, 8, 8, 256]
# ConvBlock2:
# 	Dropout layer output(ConvBlock2/dropout) shape: [1, 8, 8, 128]
# 	MaxPool2D layer output(ConvBlock2/maxpool) shape: [1, 8, 8, 128]
# 	Conv2D layer output(ConvBlock2/conv_1) shape: [1, 16, 16, 128]
# 	Conv2D layer output(ConvBlock2/conv_0) shape: [1, 16, 16, 128]
# ConvBlock1:
# 	Dropout layer output(ConvBlock1/dropout) shape: [1, 16, 16, 64]
# 	MaxPool2D layer output(ConvBlock1/maxpool) shape: [1, 16, 16, 64]
# 	Conv2D layer output(ConvBlock1/conv_1) shape: [1, 32, 32, 64]
# 	Conv2D layer output(ConvBlock1/conv_0) shape: [1, 32, 32, 64]
# ---------------------------------------------------------------------------
# VGG15 test acc before loading weights: 10.02%
# Network weights loaded from vgg15_weights.npy
# VGG15 test acc after loading weights: 76.22%

# %% [markdown]
# #### 5. VGG15 vs. VGG16
#
# VGG16 has another Block of Dense layers compared to VGG15. Additionally, the VGG nets in the paper use 4096 dense units per Dense layer (vs 512 in your nets). Is deeper and more units better? Try it out!
